# %%
# 导入所需的库
import pandas as pd
import numpy as np

# 读取Excel文件
try:
    # 假设Excel文件在同一目录下
    df = pd.read_excel('day1.xlsx')
    print("成功读取Excel文件！\n")
    
    # 显示基本信息
    print("数据集基本信息：")
    print("-" * 50)
    print(f"行数：{len(df)}")
    print(f"列数：{len(df.columns)}")
    print("-" * 50)
    
    # 遍历每一列
    for column in df.columns:
        print(f"\n分析列：{column}")
        print("-" * 30)
        
        # 数据类型
        print(f"数据类型：{df[column].dtype}")
        
        # 非空值数量
        non_null_count = df[column].count()
        null_count = df[column].isnull().sum()
        print(f"非空值数量：{non_null_count}")
        print(f"空值数量：{null_count}")
        print(f"空值比例：{(null_count/len(df))*100:.2f}%")
        
        # 唯一值统计
        unique_count = df[column].nunique()
        print(f"唯一值数量：{unique_count}")
        
        # 对数值型数据进行统计分析
        if np.issubdtype(df[column].dtype, np.number):
            print("\n数值统计：")
            print(f"最小值：{df[column].min()}")
            print(f"最大值：{df[column].max()}")
            print(f"平均值：{df[column].mean():.2f}")
            print(f"中位数：{df[column].median()}")
            print(f"标准差：{df[column].std():.2f}")
        
        # 对非数值型数据显示最常见的值
        else:
            if unique_count < 10:  # 如果唯一值较少，显示所有值
                print("\n所有唯一值：")
                print(df[column].value_counts())
            else:  # 否则只显示前5个最常见的值
                print("\n最常见的5个值：")
                print(df[column].value_counts().head())
                
except FileNotFoundError:
    print("错误：未找到Excel文件！请确保'day1.xlsx'文件在正确的位置。")
except Exception as e:
    print(f"发生错误：{str(e)}")
# Out:
# 成功读取Excel文件！
#
# 数据集基本信息：
# --------------------------------------------------
# 行数：634
# 列数：61
# --------------------------------------------------
#
# 分析列：Date
# ------------------------------
# 数据类型：datetime64[ns]
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：634
#
# 最常见的5个值：
# Date
# 2020-01-15 13:26:00    1
# 2020-01-15 20:31:00    1
# 2020-01-15 20:24:00    1
# 2020-01-15 20:25:00    1
# 2020-01-15 20:26:00    1
# Name: count, dtype: int64
#
# 分析列：PI-2
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：591
#
# 数值统计：
# 最小值：-0.055736418813467026
# 最大值：-0.05283293128013611
# 平均值：-0.05
# 中位数：-0.0545750018209219
# 标准差：0.00
#
# 分析列：TI-2
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：593
#
# 数值统计：
# 最小值：33.036041259765625
# 最大值：34.12427520751953
# 平均值：33.43
# 中位数：33.415706634521484
# 标准差：0.23
#
# 分析列：FI-2
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：631
#
# 数值统计：
# 最小值：1527.9844970703125
# 最大值：1548.2073974609375
# 平均值：1540.21
# 中位数：1540.5501708984375
# 标准差：3.49
#
# 分析列：PI-3
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：593
#
# 数值统计：
# 最小值：0.050242830067873
# 最大值：0.05508837103843689
# 平均值：0.05
# 中位数：0.0514350850135088
# 标准差：0.00
#
# 分析列：TI-3
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：587
#
# 数值统计：
# 最小值：43.21714401245117
# 最大值：44.64903259277344
# 平均值：44.10
# 中位数：44.182830810546875
# 标准差：0.38
#
# 分析列：CO2-3
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：551
#
# 数值统计：
# 最小值：14.721822738647461
# 最大值：15.87919807434082
# 平均值：15.31
# 中位数：15.320343494415283
# 标准差：0.17
#
# 分析列：O2-3
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：607
#
# 数值统计：
# 最小值：4.319326877593994
# 最大值：10.29196548461914
# 平均值：4.92
# 中位数：4.8808677196502686
# 标准差：0.45
#
# 分析列：TI-32
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：598
#
# 数值统计：
# 最小值：37.75051498413086
# 最大值：40.479225158691406
# 平均值：38.55
# 中位数：38.52852439880371
# 标准差：0.60
#
# 分析列：TI-33
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：586
#
# 数值统计：
# 最小值：51.026004791259766
# 最大值：52.62279510498047
# 平均值：51.80
# 中位数：52.08517646789551
# 标准差：0.54
#
# 分析列：TI-34
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：599
#
# 数值统计：
# 最小值：62.08382034301758
# 最大值：64.53208923339844
# 平均值：63.26
# 中位数：63.439517974853516
# 标准差：0.70
#
# 分析列：TI-35
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：613
#
# 数值统计：
# 最小值：67.16264343261719
# 最大值：68.26457214355469
# 平均值：67.67
# 中位数：67.6522445678711
# 标准差：0.25
#
# 分析列：PI-4
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：563
#
# 数值统计：
# 最小值：0.012476460076868534
# 最大值：0.015186830423772335
# 平均值：0.01
# 中位数：0.013547771144658327
# 标准差：0.00
#
# 分析列：TI-4
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：583
#
# 数值统计：
# 最小值：44.034542083740234
# 最大值：54.977291107177734
# 平均值：48.80
# 中位数：45.378347396850586
# 标准差：4.87
#
# 分析列：FI-4
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：633
#
# 数值统计：
# 最小值：1258.42919921875
# 最大值：1374.03125
# 平均值：1309.09
# 中位数：1278.1911010742188
# 标准差：45.01
#
# 分析列：CO2-4
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：603
#
# 数值统计：
# 最小值：1.4791264533996582
# 最大值：2.2186896800994873
# 平均值：1.84
# 中位数：1.8379892706871033
# 标准差：0.15
#
# 分析列：NH3-4
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：1
#
# 数值统计：
# 最小值：9.273475646972656
# 最大值：9.273475646972656
# 平均值：9.27
# 中位数：9.273475646972656
# 标准差：0.00
#
# 分析列：FI-11
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：578
#
# 数值统计：
# 最小值：2338.5390625
# 最大值：2408.104736328125
# 平均值：2374.83
# 中位数：2361.195068359375
# 标准差：25.00
#
# 分析列：TI-12
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：552
#
# 数值统计：
# 最小值：39.96621322631836
# 最大值：41.129886627197266
# 平均值：40.39
# 中位数：40.400211334228516
# 标准差：0.29
#
# 分析列：TI-13
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：591
#
# 数值统计：
# 最小值：54.06157684326172
# 最大值：56.94651794433594
# 平均值：55.54
# 中位数：55.643232345581055
# 标准差：0.69
#
# 分析列：FI-20
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：628
#
# 数值统计：
# 最小值：22.814319610595703
# 最大值：107.01612854003906
# 平均值：65.21
# 中位数：64.90810012817383
# 标准差：25.05
#
# 分析列：FI-211
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：623
#
# 数值统计：
# 最小值：1525.708984375
# 最大值：10144.5244140625
# 平均值：6511.63
# 中位数：9801.71435546875
# 标准差：4001.57
#
# 分析列：TI-211
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：570
#
# 数值统计：
# 最小值：22.166162490844727
# 最大值：23.900957107543945
# 平均值：22.67
# 中位数：22.568832397460938
# 标准差：0.36
#
# 分析列：TI-8
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：410
#
# 数值统计：
# 最小值：119.57217407226562
# 最大值：119.93506622314453
# 平均值：119.72
# 中位数：119.6769027709961
# 标准差：0.09
#
# 分析列：TI-9
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：564
#
# 数值统计：
# 最小值：49.59684753417969
# 最大值：50.771324157714844
# 平均值：50.15
# 中位数：50.14422035217285
# 标准差：0.21
#
# 分析列：TI-5
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：552
#
# 数值统计：
# 最小值：38.08852005004883
# 最大值：39.08256912231445
# 平均值：38.49
# 中位数：38.44686508178711
# 标准差：0.22
#
# 分析列：TI-7
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：573
#
# 数值统计：
# 最小值：109.10248565673828
# 最大值：110.48419952392578
# 平均值：110.06
# 中位数：110.07698059082031
# 标准差：0.17
#
# 分析列：TI-28
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：436
#
# 数值统计：
# 最小值：89.62285614013672
# 最大值：90.91150665283203
# 平均值：89.94
# 中位数：89.94338989257812
# 标准差：0.11
#
# 分析列：PI-28
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：250
#
# 数值统计：
# 最小值：0.7493448853492737
# 最大值：0.7506986856460571
# 平均值：0.75
# 中位数：0.7500410676002502
# 标准差：0.00
#
# 分析列：PI-30
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：363
#
# 数值统计：
# 最小值：0.7386516332626343
# 最大值：0.7413111329078674
# 平均值：0.74
# 中位数：0.7400153279304504
# 标准差：0.00
#
# 分析列：TI-30
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：148
#
# 数值统计：
# 最小值：35.7701530456543
# 最大值：38.16447448730469
# 平均值：37.00
# 中位数：37.1264533996582
# 标准差：0.75
#
# 分析列：FI-30
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：631
#
# 数值统计：
# 最小值：274.655029296875
# 最大值：292.61700439453125
# 平均值：284.36
# 中位数：284.4363555908203
# 标准差：3.25
#
# 分析列：FI-38
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：634
#
# 数值统计：
# 最小值：355.49566650390625
# 最大值：388.5347595214844
# 平均值：373.44
# 中位数：373.7438049316406
# 标准差：4.32
#
# 分析列：PI-38
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：273
#
# 数值统计：
# 最小值：2.4681031703948975
# 最大值：2.540076494216919
# 平均值：2.50
# 中位数：2.499814033508301
# 标准差：0.01
#
# 分析列：FI-36
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：620
#
# 数值统计：
# 最小值：360.8295593261719
# 最大值：389.6284484863281
# 平均值：369.74
# 中位数：369.7745819091797
# 标准差：3.23
#
# 分析列：TI-36
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：446
#
# 数值统计：
# 最小值：116.00205993652344
# 最大值：116.48628234863281
# 平均值：116.24
# 中位数：116.21798706054688
# 标准差：0.13
#
# 分析列：Reboiler duty
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：617
#
# 数值统计：
# 最小值：19.052631378173828
# 最大值：581.8421020507812
# 平均值：261.08
# 中位数：250.53333282470703
# 标准差：106.43
#
# 分析列：FI-19
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：627
#
# 数值统计：
# 最小值：5946.21630859375
# 最大值：6057.67822265625
# 平均值：6000.16
# 中位数：5998.752685546875
# 标准差：18.70
#
# 分析列：TI-19
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：602
#
# 数值统计：
# 最小值：44.81919479370117
# 最大值：55.873470306396484
# 平均值：49.48
# 中位数：46.07905387878418
# 标准差：4.95
#
# 分析列：PI-1
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：534
#
# 数值统计：
# 最小值：-0.023440387099981308
# 最大值：-0.02187170274555683
# 平均值：-0.02
# 中位数：-0.022614858113229275
# 标准差：0.00
#
# 分析列：TI-1
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：612
#
# 数值统计：
# 最小值：63.147762298583984
# 最大值：64.947265625
# 平均值：64.11
# 中位数：64.13346099853516
# 标准差：0.42
#
# 分析列：TI-35b
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：510
#
# 数值统计：
# 最小值：118.45695495605469
# 最大值：119.0882797241211
# 平均值：118.77
# 中位数：118.73158264160156
# 标准差：0.16
#
# 分析列：FI-35
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：576
#
# 数值统计：
# 最小值：2242.01806640625
# 最大值：2397.149169921875
# 平均值：2310.55
# 中位数：2307.1065673828125
# 标准差：31.66
#
# 分析列：TI-39
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：393
#
# 数值统计：
# 最小值：119.28736877441406
# 最大值：119.71607971191406
# 平均值：119.49
# 中位数：119.46688461303711
# 标准差：0.10
#
# 分析列：FI-23
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：620
#
# 数值统计：
# 最小值：194.98167419433594
# 最大值：207.94296264648438
# 平均值：201.48
# 中位数：201.23397064208984
# 标准差：4.02
#
# 分析列：TI-22
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：606
#
# 数值统计：
# 最小值：60.51496505737305
# 最大值：64.98666381835938
# 平均值：62.55
# 中位数：61.78598594665527
# 标准差：1.79
#
# 分析列：Level Desorber
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：596
#
# 数值统计：
# 最小值：17.686153411865234
# 最大值：18.815319061279297
# 平均值：18.31
# 中位数：18.343204498291016
# 标准差：0.25
#
# 分析列：Level Reboiler
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：535
#
# 数值统计：
# 最小值：72.55834197998047
# 最大值：73.08251190185547
# 平均值：72.96
# 中位数：72.99161529541016
# 标准差：0.12
#
# 分析列：TI-24
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：573
#
# 数值统计：
# 最小值：40.62148666381836
# 最大值：42.24277877807617
# 平均值：41.36
# 中位数：41.48056983947754
# 标准差：0.41
#
# 分析列：TI-25
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：597
#
# 数值统计：
# 最小值：35.69610595703125
# 最大值：41.28577423095703
# 平均值：36.68
# 中位数：36.537696838378906
# 标准差：0.90
#
# 分析列：FI-25
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：629
#
# 数值统计：
# 最小值：2468.12646484375
# 最大值：2664.236083984375
# 平均值：2547.01
# 中位数：2547.166015625
# 标准差：29.33
#
# 分析列：FI-16
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：573
#
# 数值统计：
# 最小值：9671.322265625
# 最大值：9803.6376953125
# 平均值：9750.16
# 中位数：9751.22314453125
# 标准差：19.04
#
# 分析列：TI-16
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：559
#
# 数值统计：
# 最小值：33.016761779785156
# 最大值：34.02243423461914
# 平均值：33.40
# 中位数：33.41552543640137
# 标准差：0.21
#
# 分析列：FI-151
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：593
#
# 数值统计：
# 最小值：18118.5390625
# 最大值：18840.69140625
# 平均值：18504.27
# 中位数：18496.37109375
# 标准差：56.51
#
# 分析列：TI-151
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：576
#
# 数值统计：
# 最小值：22.359058380126953
# 最大值：24.089601516723633
# 平均值：22.89
# 中位数：22.80476188659668
# 标准差：0.36
#
# 分析列：TI-152
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：555
#
# 数值统计：
# 最小值：30.512847900390625
# 最大值：31.60697364807129
# 平均值：30.83
# 中位数：30.77725601196289
# 标准差：0.22
#
# 分析列：TI-212
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：579
#
# 数值统计：
# 最小值：30.815135955810547
# 最大值：52.66422653198242
# 平均值：39.78
# 中位数：31.873348236083984
# 标准差：10.24
#
# 分析列：FI-241
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：597
#
# 数值统计：
# 最小值：2.29666805267334
# 最大值：458.98358154296875
# 平均值：382.47
# 中位数：407.38731384277344
# 标准差：93.33
#
# 分析列：TI-241
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：608
#
# 数值统计：
# 最小值：21.21795654296875
# 最大值：23.33143424987793
# 平均值：22.07
# 中位数：22.01302146911621
# 标准差：0.42
#
# 分析列：TI-242
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：599
#
# 数值统计：
# 最小值：34.85415267944336
# 最大值：37.41484451293945
# 平均值：35.85
# 中位数：35.885183334350586
# 标准差：0.45
#
# 分析列：CO2 capacity
# ------------------------------
# 数据类型：float64
# 非空值数量：634
# 空值数量：0
# 空值比例：0.00%
# 唯一值数量：634
#
# 数值统计：
# 最小值：0.8545633935047209
# 最大值：0.9020502067555057
# 平均值：0.88
# 中位数：0.8798453781491102
# 标准差：0.01

# %% [markdown]
# # Excel数据列分析
#
# 本代码将帮助我们分析Excel文件中的每列数据，包括：
# 1. 数据类型
# 2. 基本统计信息
# 3. 空值统计
# 4. 唯一值统计

# %%
# 导入所需的库
import pandas as pd
import numpy as np

try:
    # 读取Excel文件
    df = pd.read_excel('day1.xlsx')
    print("成功读取Excel文件！\n")
    
    # 获取第7列和第16列的列名
    column_7 = df.columns[6]  # 索引从0开始，所以第7列是索引6
    column_16 = df.columns[15]  # 第16列是索引15
    
    print(f"分析第7列（{column_7}）和第16列（{column_16}）的数据：")
    print("-" * 50)
    
    # 从第二行开始遍历（跳过第一行）
    for index in range(1, len(df)):
        print(f"\n行号：{index + 1}")  # index + 1 是实际的Excel行号
        print("-" * 30)
        
        # 显示第7列的数据
        value_7 = df.iloc[index, 6]
        print(f"第7列 ({column_7}) 的值：{value_7}")
        
        # 显示第16列的数据
        value_16 = df.iloc[index, 15]
        print(f"第16列 ({column_16}) 的值：{value_16}")
        
        # 添加一些基本的数据分析
        # 对数值型数据显示是否为空和数据类型
        for col, value in [(column_7, value_7), (column_16, value_16)]:
            print(f"\n{col}的数据分析：")
            print(f"数据类型：{type(value).__name__}")
            print(f"是否为空：{pd.isna(value)}")
            
            # 如果是数值类型，显示一些额外信息
            if isinstance(value, (int, float)) and not pd.isna(value):
                print(f"是否为整数：{float(value).is_integer()}")
                
except FileNotFoundError:
    print("错误：未找到Excel文件！请确保'day1.xlsx'文件在正确的位置。")
except Exception as e:
    print(f"发生错误：{str(e)}")
# Out:
# 成功读取Excel文件！
#
# 分析第7列（CO2-3）和第16列（CO2-4）的数据：
# --------------------------------------------------
#
# 行号：2
# ------------------------------
# 第7列 (CO2-3) 的值：15.556961059570312
# 第16列 (CO2-4) 的值：1.8146437406539917
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：3
# ------------------------------
# 第7列 (CO2-3) 的值：15.476249694824219
# 第16列 (CO2-4) 的值：1.7939022779464722
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：4
# ------------------------------
# 第7列 (CO2-3) 的值：15.56407642364502
# 第16列 (CO2-4) 的值：1.880946397781372
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：5
# ------------------------------
# 第7列 (CO2-3) 的值：15.636453628540039
# 第16列 (CO2-4) 的值：1.8756800889968872
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：6
# ------------------------------
# 第7列 (CO2-3) 的值：15.598077774047852
# 第16列 (CO2-4) 的值：1.887284278869629
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：7
# ------------------------------
# 第7列 (CO2-3) 的值：15.555132865905762
# 第16列 (CO2-4) 的值：1.8837871551513672
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：8
# ------------------------------
# 第7列 (CO2-3) 的值：15.424166679382324
# 第16列 (CO2-4) 的值：1.8936803340911865
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：624
# ------------------------------
# 第7列 (CO2-3) 的值：15.419720649719238
# 第16列 (CO2-4) 的值：2.0178403854370117
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：625
# ------------------------------
# 第7列 (CO2-3) 的值：15.281044960021973
# 第16列 (CO2-4) 的值：2.0570778846740723
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：626
# ------------------------------
# 第7列 (CO2-3) 的值：15.288936614990234
# 第16列 (CO2-4) 的值：2.052027702331543
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：627
# ------------------------------
# 第7列 (CO2-3) 的值：15.20792007446289
# 第16列 (CO2-4) 的值：2.032017230987549
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：628
# ------------------------------
# 第7列 (CO2-3) 的值：15.227385520935059
# 第16列 (CO2-4) 的值：2.0332465171813965
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：629
# ------------------------------
# 第7列 (CO2-3) 的值：15.382684707641602
# 第16列 (CO2-4) 的值：2.025986671447754
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：630
# ------------------------------
# 第7列 (CO2-3) 的值：15.19604206085205
# 第16列 (CO2-4) 的值：2.0501089096069336
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：631
# ------------------------------
# 第7列 (CO2-3) 的值：15.433609008789062
# 第16列 (CO2-4) 的值：2.081382989883423
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：632
# ------------------------------
# 第7列 (CO2-3) 的值：15.375740051269531
# 第16列 (CO2-4) 的值：2.1023733615875244
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：633
# ------------------------------
# 第7列 (CO2-3) 的值：15.465893745422363
# 第16列 (CO2-4) 的值：2.057966709136963
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# 行号：634
# ------------------------------
# 第7列 (CO2-3) 的值：15.49726390838623
# 第16列 (CO2-4) 的值：2.055341958999634
#
# CO2-3的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False
#
# CO2-4的数据分析：
# 数据类型：float64
# 是否为空：False
# 是否为整数：False

# %%
# 导入所需的库
import pandas as pd
import numpy as np

try:
    # 读取Excel文件
    df = pd.read_excel('day1.xlsx')
    print("成功读取Excel文件！\n")
    
    # 获取第7列、第16列和最后一列的列名
    column_7 = df.columns[6]      # 第7列
    column_16 = df.columns[15]    # 第16列
    last_column = df.columns[-1]  # 最后一列
    
    print(f"分析计算结果：")
    print("-" * 50)
    
    # 计数器，用于统计匹配成功的行数
    success_count = 0
    total_count = 0
    
    # 从第二行开始遍历（跳过第一行）
    for index in range(1, len(df)):
        print(f"\n行号：{index + 1}")  # index + 1 是实际的Excel行号
        print("-" * 30)
        
        # 获取各列的值
        value_7 = df.iloc[index, 6]
        value_16 = df.iloc[index, 15]
        expected_result = df.iloc[index, -1]  # 最后一列的值
        
        print(f"第7列 ({column_7}) 的值：{value_7}")
        print(f"第16列 ({column_16}) 的值：{value_16}")
        print(f"最后一列 ({last_column}) 的值：{expected_result}")
        
        # 检查数据是否为数值类型且不为空
        if (isinstance(value_7, (int, float)) and 
            isinstance(value_16, (int, float)) and 
            not pd.isna(value_7) and 
            not pd.isna(value_16) and 
            value_7 != 0):  # 避免除以零
            
            # 计算结果
            calculated_result = (value_7 - value_16) / value_7
            print(f"\n计算结果：{calculated_result:.6f}")
            
            # 比较计算结果与预期结果
            # 使用近似比较来处理浮点数
            if pd.isna(expected_result):
                print("警告：Excel中的对应结果为空值")
            else:
                total_count += 1
                # 使用相对误差来比较浮点数
                relative_error = abs(calculated_result - expected_result) / abs(expected_result)
                if relative_error < 1e-10:  # 允许很小的误差
                    print("✓ 计算结果与Excel匹配")
                    success_count += 1
                else:
                    print(f"✗ 计算结果与Excel不匹配（Excel中的值：{expected_result:.6f}）")
        else:
            print("\n警告：该行数据不完整或不是数值类型，跳过计算")
    
    # 打印总结
    print("\n" + "=" * 50)
    print(f"计算总结：")
    print(f"总计算行数：{total_count}")
    print(f"匹配成功行数：{success_count}")
    print(f"成功率：{(success_count/total_count*100):.2f}%" if total_count > 0 else "无有效计算")
    
except FileNotFoundError:
    print("错误：未找到Excel文件！请确保'day1.xlsx'文件在正确的位置。")
except Exception as e:
    print(f"发生错误：{str(e)}")
# Out:
# 成功读取Excel文件！
#
# 分析计算结果：
# --------------------------------------------------
#
# 行号：2
# ------------------------------
# 第7列 (CO2-3) 的值：15.556961059570312
# 第16列 (CO2-4) 的值：1.8146437406539917
# 最后一列 (CO2 capacity) 的值：0.8833548702921217
#
# 计算结果：0.883355
# ✓ 计算结果与Excel匹配
#
# 行号：3
# ------------------------------
# 第7列 (CO2-3) 的值：15.476249694824219
# 第16列 (CO2-4) 的值：1.7939022779464722
# 最后一列 (CO2 capacity) 的值：0.884086757882537
#
# 计算结果：0.884087
# ✓ 计算结果与Excel匹配
#
# 行号：4
# ------------------------------
# 第7列 (CO2-3) 的值：15.56407642364502
# 第16列 (CO2-4) 的值：1.880946397781372
# 最后一列 (CO2 capacity) 的值：0.8791482162781064
#
# 计算结果：0.879148
# ✓ 计算结果与Excel匹配
#
# 行号：5
# ------------------------------
# 第7列 (CO2-3) 的值：15.636453628540039
# 第16列 (CO2-4) 的值：1.8756800889968872
# 最后一列 (CO2 capacity) 的值：0.8800444056206358
#
# 计算结果：0.880044
# ✓ 计算结果与Excel匹配
#
# 行号：6
# ------------------------------
# 第7列 (CO2-3) 的值：15.598077774047852
# 第16列 (CO2-4) 的值：1.887284278869629
# 最后一列 (CO2 capacity) 的值：0.8790053296176212
#
# 计算结果：0.879005
# ✓ 计算结果与Excel匹配
#
# 行号：7
# ------------------------------
# 第7列 (CO2-3) 的值：15.555132865905762
# 第16列 (CO2-4) 的值：1.8837871551513672
# 最后一列 (CO2 capacity) 的值：0.8788961064241173
#
# 计算结果：0.878896
# ✓ 计算结果与Excel匹配
#
# 行号：8
# ------------------------------
# 第7列 (CO2-3) 的值：15.424166679382324
# 第16列 (CO2-4) 的值：1.8936803340911865
# 最后一列 (CO2 capacity) 的值：0.8772264088261901
#
# 计算结果：0.877226
# ✓ 计算结果与Excel匹配
#
# 行号：9
# ------------------------------
# 第7列 (CO2-3) 的值：15.47350788116455
# 第16列 (CO2-4) 的值：1.8548108339309692
# 最后一列 (CO2 capacity) 的值：0.8801299066652639
#
# 计算结果：0.880130
# ✓ 计算结果与Excel匹配
#
# 行号：10
# ------------------------------
# 第7列 (CO2-3) 的值：15.36100959777832
# 第16列 (CO2-4) 的值：1.8429107666015625
# 最后一列 (CO2 capacity) 的值：0.8800267160260024
#
# 计算结果：0.880027
# ✓ 计算结果与Excel匹配
#
# 行号：11
# ------------------------------
# 第7列 (CO2-3) 的值：15.394927978515625
# 第16列 (CO2-4) 的值：1.846258282661438
# 最后一列 (CO2 capacity) 的值：0.8800736005236282
#
# 计算结果：0.880074
# ✓ 计算结果与Excel匹配
#
# 行号：12
# ------------------------------
# 第7列 (CO2-3) 的值：15.443659782409668
# 第16列 (CO2-4) 的值：1.849364995956421
# 最后一列 (CO2 capacity) 的值：0.8802508587981944
#
# 计算结果：0.880251
# ✓ 计算结果与Excel匹配
#
# 行号：13
# ------------------------------
# 第7列 (CO2-3) 的值：15.123747825622559
# 第16列 (CO2-4) 的值：1.8462251424789429
# 最后一列 (CO2 capacity) 的值：0.877925421412338
#
# 计算结果：0.877925
# ✓ 计算结果与Excel匹配
#
# 行号：14
# ------------------------------
# 第7列 (CO2-3) 的值：15.251474380493164
# 第16列 (CO2-4) 的值：1.8138214349746704
# 最后一列 (CO2 capacity) 的值：0.8810723875132642
#
# 计算结果：0.881072
# ✓ 计算结果与Excel匹配
#
# 行号：15
# ------------------------------
# 第7列 (CO2-3) 的值：15.467720985412598
# 第16列 (CO2-4) 的值：1.8310905694961548
# 最后一列 (CO2 capacity) 的值：0.8816185932482857
#
# 计算结果：0.881619
# ✓ 计算结果与Excel匹配
#
# 行号：16
# ------------------------------
# 第7列 (CO2-3) 的值：15.194242477416992
# 第16列 (CO2-4) 的值：1.7663661241531372
# 最后一列 (CO2 capacity) 的值：0.8837476677907132
#
# 计算结果：0.883748
# ✓ 计算结果与Excel匹配
#
# 行号：17
# ------------------------------
# 第7列 (CO2-3) 的值：15.29380989074707
# 第16列 (CO2-4) 的值：1.7563484907150269
# 最后一列 (CO2 capacity) 的值：0.8851595185724365
#
# 计算结果：0.885160
# ✓ 计算结果与Excel匹配
#
# 行号：18
# ------------------------------
# 第7列 (CO2-3) 的值：15.2548246383667
# 第16列 (CO2-4) 的值：1.7638410329818726
# 最后一列 (CO2 capacity) 的值：0.8843748732092457
#
# 计算结果：0.884375
# ✓ 计算结果与Excel匹配
#
# 行号：19
# ------------------------------
# 第7列 (CO2-3) 的值：15.158469200134277
# 第16列 (CO2-4) 的值：1.7308557033538818
# 最后一列 (CO2 capacity) 的值：0.8858159303224002
#
# 计算结果：0.885816
# ✓ 计算结果与Excel匹配
#
# 行号：20
# ------------------------------
# 第7列 (CO2-3) 的值：15.298683166503906
# 第16列 (CO2-4) 的值：1.7265613079071045
# 最后一列 (CO2 capacity) 的值：0.8871431423792494
#
# 计算结果：0.887143
# ✓ 计算结果与Excel匹配
#
# 行号：21
# ------------------------------
# 第7列 (CO2-3) 的值：15.15705680847168
# 第16列 (CO2-4) 的值：1.758632779121399
# 最后一列 (CO2 capacity) 的值：0.8839726734982973
#
# 计算结果：0.883973
# ✓ 计算结果与Excel匹配
#
# 行号：22
# ------------------------------
# 第7列 (CO2-3) 的值：15.184772491455078
# 第16列 (CO2-4) 的值：1.7777295112609863
# 最后一列 (CO2 capacity) 的值：0.8829268260514692
#
# 计算结果：0.882927
# ✓ 计算结果与Excel匹配
#
# 行号：23
# ------------------------------
# 第7列 (CO2-3) 的值：15.217971801757812
# 第16列 (CO2-4) 的值：1.7354243993759155
# 最后一列 (CO2 capacity) 的值：0.8859621753816459
#
# 计算结果：0.885962
# ✓ 计算结果与Excel匹配
#
# 行号：24
# ------------------------------
# 第7列 (CO2-3) 的值：15.493609428405762
# 第16列 (CO2-4) 的值：1.7426427602767944
# 最后一列 (CO2 capacity) 的值：0.8875250619728506
#
# 计算结果：0.887525
# ✓ 计算结果与Excel匹配
#
# 行号：25
# ------------------------------
# 第7列 (CO2-3) 的值：15.256845474243164
# 第16列 (CO2-4) 的值：1.710496425628662
# 最后一列 (CO2 capacity) 的值：0.8878866258089624
#
# 计算结果：0.887887
# ✓ 计算结果与Excel匹配
#
# 行号：26
# ------------------------------
# 第7列 (CO2-3) 的值：15.134822845458984
# 第16列 (CO2-4) 的值：1.712307333946228
# 最后一列 (CO2 capacity) 的值：0.8868630738905553
#
# 计算结果：0.886863
# ✓ 计算结果与Excel匹配
#
# 行号：27
# ------------------------------
# 第7列 (CO2-3) 的值：15.0081205368042
# 第16列 (CO2-4) 的值：1.7248252630233765
# 最后一列 (CO2 capacity) 的值：0.8850738665915154
#
# 计算结果：0.885074
# ✓ 计算结果与Excel匹配
#
# 行号：28
# ------------------------------
# 第7列 (CO2-3) 的值：15.155838012695312
# 第16列 (CO2-4) 的值：1.6754595041275024
# 最后一列 (CO2 capacity) 的值：0.889451213273456
#
# 计算结果：0.889451
# ✓ 计算结果与Excel匹配
#
# 行号：29
# ------------------------------
# 第7列 (CO2-3) 的值：15.231067657470703
# 第16列 (CO2-4) 的值：1.6869059801101685
# 最后一列 (CO2 capacity) 的值：0.8892457168435756
#
# 计算结果：0.889246
# ✓ 计算结果与Excel匹配
#
# 行号：30
# ------------------------------
# 第7列 (CO2-3) 的值：15.160711288452148
# 第16列 (CO2-4) 的值：1.679870367050171
# 最后一列 (CO2 capacity) 的值：0.8891958078292987
#
# 计算结果：0.889196
# ✓ 计算结果与Excel匹配
#
# 行号：31
# ------------------------------
# 第7列 (CO2-3) 的值：15.258423805236816
# 第16列 (CO2-4) 的值：1.6681996583938599
# 最后一列 (CO2 capacity) 的值：0.8906702501066119
#
# 计算结果：0.890670
# ✓ 计算结果与Excel匹配
#
# 行号：32
# ------------------------------
# 第7列 (CO2-3) 的值：15.262134552001953
# 第16列 (CO2-4) 的值：1.683982014656067
# 最后一列 (CO2 capacity) 的值：0.8896627461304109
#
# 计算结果：0.889663
# ✓ 计算结果与Excel匹配
#
# 行号：33
# ------------------------------
# 第7列 (CO2-3) 的值：15.137564659118652
# 第16列 (CO2-4) 的值：1.6989670991897583
# 最后一列 (CO2 capacity) 的值：0.8877648328876783
#
# 计算结果：0.887765
# ✓ 计算结果与Excel匹配
#
# 行号：34
# ------------------------------
# 第7列 (CO2-3) 的值：15.196346282958984
# 第16列 (CO2-4) 的值：1.709391713142395
# 最后一列 (CO2 capacity) 的值：0.8875129796785897
#
# 计算结果：0.887513
# ✓ 计算结果与Excel匹配
#
# 行号：35
# ------------------------------
# 第7列 (CO2-3) 的值：15.378480911254883
# 第16列 (CO2-4) 的值：1.7075560092926025
# 最后一列 (CO2 capacity) 的值：0.8889645850493002
#
# 计算结果：0.888965
# ✓ 计算结果与Excel匹配
#
# 行号：36
# ------------------------------
# 第7列 (CO2-3) 的值：15.258784294128418
# 第16列 (CO2-4) 的值：1.697413682937622
# 最后一列 (CO2 capacity) 的值：0.888758262111957
#
# 计算结果：0.888758
# ✓ 计算结果与Excel匹配
#
# 行号：37
# ------------------------------
# 第7列 (CO2-3) 的值：15.3136625289917
# 第16列 (CO2-4) 的值：1.7623364925384521
# 最后一列 (CO2 capacity) 的值：0.8849173743249199
#
# 计算结果：0.884917
# ✓ 计算结果与Excel匹配
#
# 行号：38
# ------------------------------
# 第7列 (CO2-3) 的值：15.389750480651855
# 第16列 (CO2-4) 的值：1.7489475011825562
# 最后一列 (CO2 capacity) 的值：0.8863563445436397
#
# 计算结果：0.886356
# ✓ 计算结果与Excel匹配
#
# 行号：39
# ------------------------------
# 第7列 (CO2-3) 的值：15.327617645263672
# 第16列 (CO2-4) 的值：1.7642065286636353
# 最后一列 (CO2 capacity) 的值：0.8849001475967281
#
# 计算结果：0.884900
# ✓ 计算结果与Excel匹配
#
# 行号：40
# ------------------------------
# 第7列 (CO2-3) 的值：15.331549644470215
# 第16列 (CO2-4) 的值：1.7925649881362915
# 最后一列 (CO2 capacity) 的值：0.8830799867133565
#
# 计算结果：0.883080
# ✓ 计算结果与Excel匹配
#
# 行号：41
# ------------------------------
# 第7列 (CO2-3) 的值：15.367212295532227
# 第16列 (CO2-4) 的值：1.7839428186416626
# 最后一列 (CO2 capacity) 的值：0.8839123984016076
#
# 计算结果：0.883912
# ✓ 计算结果与Excel匹配
#
# 行号：42
# ------------------------------
# 第7列 (CO2-3) 的值：15.383659362792969
# 第16列 (CO2-4) 的值：1.78823721408844
# 最后一列 (CO2 capacity) 的值：0.8837573576015676
#
# 计算结果：0.883757
# ✓ 计算结果与Excel匹配
#
# 行号：43
# ------------------------------
# 第7列 (CO2-3) 的值：15.332601547241211
# 第16列 (CO2-4) 的值：1.786725401878357
# 最后一列 (CO2 capacity) 的值：0.8834688688430802
#
# 计算结果：0.883469
# ✓ 计算结果与Excel匹配
#
# 行号：44
# ------------------------------
# 第7列 (CO2-3) 的值：15.338886260986328
# 第16列 (CO2-4) 的值：1.7824808359146118
# 最后一列 (CO2 capacity) 的值：0.8837933337801546
#
# 计算结果：0.883793
# ✓ 计算结果与Excel匹配
#
# 行号：45
# ------------------------------
# 第7列 (CO2-3) 的值：15.329444885253906
# 第16列 (CO2-4) 的值：1.7829376459121704
# 最后一列 (CO2 capacity) 的值：0.8836919628037373
#
# 计算结果：0.883692
# ✓ 计算结果与Excel匹配
#
# 行号：46
# ------------------------------
# 第7列 (CO2-3) 的值：15.4215087890625
# 第16列 (CO2-4) 的值：1.7856206893920898
# 最后一列 (CO2 capacity) 的值：0.8842123222950456
#
# 计算结果：0.884212
# ✓ 计算结果与Excel匹配
#
# 行号：47
# ------------------------------
# 第7列 (CO2-3) 的值：15.444877624511719
# 第16列 (CO2-4) 的值：1.7979227304458618
# 最后一列 (CO2 capacity) 的值：0.8835910018741439
#
# 计算结果：0.883591
# ✓ 计算结果与Excel匹配
#
# 行号：48
# ------------------------------
# 第7列 (CO2-3) 的值：15.391273498535156
# 第16列 (CO2-4) 的值：1.7788259983062744
# 最后一列 (CO2 capacity) 的值：0.8844263277840153
#
# 计算结果：0.884426
# ✓ 计算结果与Excel匹配
#
# 行号：49
# ------------------------------
# 第7列 (CO2-3) 的值：15.294723510742188
# 第16列 (CO2-4) 的值：1.860429286956787
# 最后一列 (CO2 capacity) 的值：0.8783613652348718
#
# 计算结果：0.878361
# ✓ 计算结果与Excel匹配
#
# 行号：50
# ------------------------------
# 第7列 (CO2-3) 的值：15.276144981384277
# 第16列 (CO2-4) 的值：1.8586848974227905
# 最后一列 (CO2 capacity) 的值：0.8783276212887604
#
# 计算结果：0.878328
# ✓ 计算结果与Excel匹配
#
# 行号：51
# ------------------------------
# 第7列 (CO2-3) 的值：15.42264461517334
# 第16列 (CO2-4) 的值：1.8704718351364136
# 最后一列 (CO2 capacity) 的值：0.8787191249096036
#
# 计算结果：0.878719
# ✓ 计算结果与Excel匹配
#
# 行号：52
# ------------------------------
# 第7列 (CO2-3) 的值：15.323131561279297
# 第16列 (CO2-4) 的值：1.9204024076461792
# 最后一列 (CO2 capacity) 的值：0.8746729805218844
#
# 计算结果：0.874673
# ✓ 计算结果与Excel匹配
#
# 行号：53
# ------------------------------
# 第7列 (CO2-3) 的值：15.389446258544922
# 第16列 (CO2-4) 的值：1.9278533458709717
# 最后一列 (CO2 capacity) 的值：0.8747288685061986
#
# 计算结果：0.874729
# ✓ 计算结果与Excel匹配
#
# 行号：54
# ------------------------------
# 第7列 (CO2-3) 的值：15.303556442260742
# 第16列 (CO2-4) 的值：1.9044620990753174
# 最后一列 (CO2 capacity) 的值：0.8755542800615843
#
# 计算结果：0.875554
# ✓ 计算结果与Excel匹配
#
# 行号：55
# ------------------------------
# 第7列 (CO2-3) 的值：15.48621654510498
# 第16列 (CO2-4) 的值：2.032141923904419
# 最后一列 (CO2 capacity) 的值：0.8687773790334375
#
# 计算结果：0.868777
# ✓ 计算结果与Excel匹配
#
# 行号：56
# ------------------------------
# 第7列 (CO2-3) 的值：15.443659782409668
# 第16列 (CO2-4) 的值：2.0372254848480225
# 最后一列 (CO2 capacity) 的值：0.8680866120109417
#
# 计算结果：0.868087
# ✓ 计算结果与Excel匹配
#
# 行号：57
# ------------------------------
# 第7列 (CO2-3) 的值：15.54690933227539
# 第16列 (CO2-4) 的值：2.0121896266937256
# 最后一列 (CO2 capacity) 的值：0.8705730133437892
#
# 计算结果：0.870573
# ✓ 计算结果与Excel匹配
#
# 行号：58
# ------------------------------
# 第7列 (CO2-3) 的值：15.446234703063965
# 第16列 (CO2-4) 的值：2.0913257598876953
# 最后一列 (CO2 capacity) 的值：0.8646061127458556
#
# 计算结果：0.864606
# ✓ 计算结果与Excel匹配
#
# 行号：59
# ------------------------------
# 第7列 (CO2-3) 的值：15.48569107055664
# 第16列 (CO2-4) 的值：2.089672803878784
# 最后一列 (CO2 capacity) 的值：0.8650578269734481
#
# 计算结果：0.865058
# ✓ 计算结果与Excel匹配
#
# 行号：60
# ------------------------------
# 第7列 (CO2-3) 的值：15.426908493041992
# 第16列 (CO2-4) 的值：2.1079471111297607
# 最后一列 (CO2 capacity) 的值：0.8633590708027788
#
# 计算结果：0.863359
# ✓ 计算结果与Excel匹配
#
# 行号：61
# ------------------------------
# 第7列 (CO2-3) 的值：15.28525447845459
# 第16列 (CO2-4) 的值：2.0640223026275635
# 最后一列 (CO2 capacity) 的值：0.8649664416423739
#
# 计算结果：0.864966
# ✓ 计算结果与Excel匹配
#
# 行号：62
# ------------------------------
# 第7列 (CO2-3) 的值：15.406806945800781
# 第16列 (CO2-4) 的值：2.058149576187134
# 最后一列 (CO2 capacity) 的值：0.866412970356061
#
# 计算结果：0.866413
# ✓ 计算结果与Excel匹配
#
# 行号：63
# ------------------------------
# 第7列 (CO2-3) 的值：15.502137184143066
# 第16列 (CO2-4) 的值：2.0713984966278076
# 最后一列 (CO2 capacity) 的值：0.8663798112465025
#
# 计算结果：0.866380
# ✓ 计算结果与Excel匹配
#
# 行号：64
# ------------------------------
# 第7列 (CO2-3) 的值：15.404288291931152
# 第16列 (CO2-4) 的值：1.9947375059127808
# 最后一列 (CO2 capacity) 的值：0.8705076490318845
#
# 计算结果：0.870508
# ✓ 计算结果与Excel匹配
#
# 行号：65
# ------------------------------
# 第7列 (CO2-3) 的值：15.54020881652832
# 第16列 (CO2-4) 的值：2.0134687423706055
# 最后一列 (CO2 capacity) 的值：0.870434897874145
#
# 计算结果：0.870435
# ✓ 计算结果与Excel匹配
#
# 行号：66
# ------------------------------
# 第7列 (CO2-3) 的值：15.303556442260742
# 第16列 (CO2-4) 的值：2.016209840774536
# 最后一列 (CO2 capacity) 的值：0.8682522034416277
#
# 计算结果：0.868252
# ✓ 计算结果与Excel匹配
#
# 行号：67
# ------------------------------
# 第7列 (CO2-3) 的值：15.398361206054688
# 第16列 (CO2-4) 的值：2.0476295948028564
# 最后一列 (CO2 capacity) 的值：0.8670228885137646
#
# 计算结果：0.867023
# ✓ 计算结果与Excel匹配
#
# 行号：68
# ------------------------------
# 第7列 (CO2-3) 的值：15.492086410522461
# 第16列 (CO2-4) 的值：2.0303726196289062
# 最后一列 (CO2 capacity) 的值：0.868941305526811
#
# 计算结果：0.868941
# ✓ 计算结果与Excel匹配
#
# 行号：69
# ------------------------------
# 第7列 (CO2-3) 的值：15.463761329650879
# 第16列 (CO2-4) 的值：2.062809467315674
# 最后一列 (CO2 capacity) 的值：0.8666036403859678
#
# 计算结果：0.866604
# ✓ 计算结果与Excel匹配
#
# 行号：70
# ------------------------------
# 第7列 (CO2-3) 的值：15.425191879272461
# 第16列 (CO2-4) 的值：2.0346670150756836
# 最后一列 (CO2 capacity) 的值：0.8680945409949967
#
# 计算结果：0.868095
# ✓ 计算结果与Excel匹配
#
# 行号：71
# ------------------------------
# 第7列 (CO2-3) 的值：15.570362091064453
# 第16列 (CO2-4) 的值：2.0275399684906006
# 最后一列 (CO2 capacity) 的值：0.8697820926300636
#
# 计算结果：0.869782
# ✓ 计算结果与Excel匹配
#
# 行号：72
# ------------------------------
# 第7列 (CO2-3) 的值：15.459193229675293
# 第16列 (CO2-4) 的值：2.035306692123413
# 最后一列 (CO2 capacity) 的值：0.8683432788577569
#
# 计算结果：0.868343
# ✓ 计算结果与Excel匹配
#
# 行号：73
# ------------------------------
# 第7列 (CO2-3) 的值：15.495686531066895
# 第16列 (CO2-4) 的值：2.039717435836792
# 最后一列 (CO2 capacity) 的值：0.8683686952657814
#
# 计算结果：0.868369
# ✓ 计算结果与Excel匹配
#
# 行号：74
# ------------------------------
# 第7列 (CO2-3) 的值：15.487213134765625
# 第16列 (CO2-4) 的值：2.025986671447754
# 最后一列 (CO2 capacity) 的值：0.8691832640373607
#
# 计算结果：0.869183
# ✓ 计算结果与Excel匹配
#
# 行号：75
# ------------------------------
# 第7列 (CO2-3) 的值：15.472594261169434
# 第16列 (CO2-4) 的值：2.044991970062256
# 最后一列 (CO2 capacity) 的值：0.8678313451807859
#
# 计算结果：0.867831
# ✓ 计算结果与Excel匹配
#
# 行号：76
# ------------------------------
# 第7列 (CO2-3) 的值：15.393627166748047
# 第16列 (CO2-4) 的值：1.9999457597732544
# 最后一列 (CO2 capacity) 的值：0.8700796285300868
#
# 计算结果：0.870080
# ✓ 计算结果与Excel匹配
#
# 行号：77
# ------------------------------
# 第7列 (CO2-3) 的值：15.33523178100586
# 第16列 (CO2-4) 的值：1.9993975162506104
# 最后一列 (CO2 capacity) 的值：0.8696206523120795
#
# 计算结果：0.869621
# ✓ 计算结果与Excel匹配
#
# 行号：78
# ------------------------------
# 第7列 (CO2-3) 的值：15.357465744018555
# 第16列 (CO2-4) 的值：2.003692150115967
# 最后一列 (CO2 capacity) 的值：0.8695297659448553
#
# 计算结果：0.869530
# ✓ 计算结果与Excel匹配
#
# 行号：79
# ------------------------------
# 第7列 (CO2-3) 的值：15.302824974060059
# 第16列 (CO2-4) 的值：1.9383153915405273
# 最后一列 (CO2 capacity) 的值：0.873336106579917
#
# 计算结果：0.873336
# ✓ 计算结果与Excel匹配
#
# 行号：80
# ------------------------------
# 第7列 (CO2-3) 的值：15.361120223999023
# 第16列 (CO2-4) 的值：1.945305347442627
# 最后一列 (CO2 capacity) 的值：0.8733617523282298
#
# 计算结果：0.873362
# ✓ 计算结果与Excel匹配
#
# 行号：81
# ------------------------------
# 第7列 (CO2-3) 的值：15.41716194152832
# 第16列 (CO2-4) 的值：1.934523582458496
# 最后一列 (CO2 capacity) 的值：0.8745214203628762
#
# 计算结果：0.874521
# ✓ 计算结果与Excel匹配
#
# 行号：82
# ------------------------------
# 第7列 (CO2-3) 的值：15.281414031982422
# 第16列 (CO2-4) 的值：1.900122046470642
# 最后一列 (CO2 capacity) 的值：0.8756579697079155
#
# 计算结果：0.875658
# ✓ 计算结果与Excel匹配
#
# 行号：83
# ------------------------------
# 第7列 (CO2-3) 的值：15.471071243286133
# 第16列 (CO2-4) 的值：1.893040657043457
# 最后一列 (CO2 capacity) 的值：0.8776399754564529
#
# 计算结果：0.877640
# ✓ 计算结果与Excel匹配
#
# 行号：84
# ------------------------------
# 第7列 (CO2-3) 的值：15.358379364013672
# 第16列 (CO2-4) 的值：1.9128683805465698
# 最后一列 (CO2 capacity) 的值：0.8754511569737218
#
# 计算结果：0.875451
# ✓ 计算结果与Excel匹配
#
# 行号：85
# ------------------------------
# 第7列 (CO2-3) 的值：15.093918800354004
# 第16列 (CO2-4) 的值：1.867136836051941
# 最后一列 (CO2 capacity) 的值：0.8762987358850671
#
# 计算结果：0.876299
# ✓ 计算结果与Excel匹配
#
# 行号：86
# ------------------------------
# 第7列 (CO2-3) 的值：15.132691383361816
# 第16列 (CO2-4) 的值：1.818006157875061
# 最后一列 (CO2 capacity) 的值：0.8798623383098968
#
# 计算结果：0.879862
# ✓ 计算结果与Excel匹配
#
# 行号：87
# ------------------------------
# 第7列 (CO2-3) 的值：15.193131446838379
# 第16列 (CO2-4) 的值：1.8795785903930664
# 最后一列 (CO2 capacity) 的值：0.8762876108213887
#
# 计算结果：0.876288
# ✓ 计算结果与Excel匹配
#
# 行号：88
# ------------------------------
# 第7列 (CO2-3) 的值：15.073664665222168
# 第16列 (CO2-4) 的值：1.752556562423706
# 最后一列 (CO2 capacity) 的值：0.8837338761776232
#
# 计算结果：0.883734
# ✓ 计算结果与Excel匹配
#
# 行号：89
# ------------------------------
# 第7列 (CO2-3) 的值：15.046497344970703
# 第16列 (CO2-4) 的值：1.7630187273025513
# 最后一列 (CO2 capacity) 的值：0.8828286286913253
#
# 计算结果：0.882829
# ✓ 计算结果与Excel匹配
#
# 行号：90
# ------------------------------
# 第7列 (CO2-3) 的值：15.12806224822998
# 第16列 (CO2-4) 的值：1.7048149108886719
# 最后一列 (CO2 capacity) 的值：0.8873077805395638
#
# 计算结果：0.887308
# ✓ 计算结果与Excel匹配
#
# 行号：91
# ------------------------------
# 第7列 (CO2-3) 的值：15.14657974243164
# 第16列 (CO2-4) 的值：1.69127357006073
# 最后一列 (CO2 capacity) 的值：0.8883395724433554
#
# 计算结果：0.888340
# ✓ 计算结果与Excel匹配
#
# 行号：92
# ------------------------------
# 第7列 (CO2-3) 的值：15.186904907226562
# 第16列 (CO2-4) 的值：1.7096575498580933
# 最后一列 (CO2 capacity) 的值：0.8874255445528887
#
# 计算结果：0.887426
# ✓ 计算结果与Excel匹配
#
# 行号：93
# ------------------------------
# 第7列 (CO2-3) 的值：15.144451141357422
# 第16列 (CO2-4) 的值：1.711759090423584
# 最后一列 (CO2 capacity) 的值：0.8869712032185172
#
# 计算结果：0.886971
# ✓ 计算结果与Excel匹配
#
# 行号：94
# ------------------------------
# 第7列 (CO2-3) 的值：15.314977645874023
# 第16列 (CO2-4) 的值：1.722696304321289
# 最后一列 (CO2 capacity) 的值：0.8875155847984278
#
# 计算结果：0.887516
# ✓ 计算结果与Excel匹配
#
# 行号：95
# ------------------------------
# 第7列 (CO2-3) 的值：15.223149299621582
# 第16列 (CO2-4) 的值：1.715779423713684
# 最后一列 (CO2 capacity) 的值：0.8872914276839987
#
# 计算结果：0.887291
# ✓ 计算结果与Excel匹配
#
# 行号：96
# ------------------------------
# 第7列 (CO2-3) 的值：15.29929256439209
# 第16列 (CO2-4) 的值：1.711759090423584
# 最后一列 (CO2 capacity) 的值：0.8881151475978981
#
# 计算结果：0.888115
# ✓ 计算结果与Excel匹配
#
# 行号：97
# ------------------------------
# 第7列 (CO2-3) 的值：15.517518043518066
# 第16列 (CO2-4) 的值：1.761757731437683
# 最后一列 (CO2 capacity) 的值：0.8864665259935948
#
# 计算结果：0.886467
# ✓ 计算结果与Excel匹配
#
# 行号：98
# ------------------------------
# 第7列 (CO2-3) 的值：15.352896690368652
# 第16列 (CO2-4) 的值：1.7565312385559082
# 最后一列 (CO2 capacity) 的值：0.885589587816491
#
# 计算结果：0.885590
# ✓ 计算结果与Excel匹配
#
# 行号：99
# ------------------------------
# 第7列 (CO2-3) 的值：15.573136329650879
# 第16列 (CO2-4) 的值：1.7219825983047485
# 最后一列 (CO2 capacity) 的值：0.8894260884991975
#
# 计算结果：0.889426
# ✓ 计算结果与Excel匹配
#
# 行号：100
# ------------------------------
# 第7列 (CO2-3) 的值：15.264631271362305
# 第16列 (CO2-4) 的值：1.7954374551773071
# 最后一列 (CO2 capacity) 的值：0.8823792449840767
#
# 计算结果：0.882379
# ✓ 计算结果与Excel匹配
#
# 行号：101
# ------------------------------
# 第7列 (CO2-3) 的值：15.418989181518555
# 第16列 (CO2-4) 的值：1.7780036926269531
# 最后一列 (CO2 capacity) 的值：0.8846874025465887
#
# 计算结果：0.884687
# ✓ 计算结果与Excel匹配
#
# 行号：102
# ------------------------------
# 第7列 (CO2-3) 的值：15.501893997192383
# 第16列 (CO2-4) 的值：1.7655770778656006
# 最后一列 (CO2 capacity) 的值：0.8861057185537863
#
# 计算结果：0.886106
# ✓ 计算结果与Excel匹配
#
# 行号：103
# ------------------------------
# 第7列 (CO2-3) 的值：15.543559074401855
# 第16列 (CO2-4) 的值：1.7879722118377686
# 最后一列 (CO2 capacity) 的值：0.8849702179996654
#
# 计算结果：0.884970
# ✓ 计算结果与Excel匹配
#
# 行号：104
# ------------------------------
# 第7列 (CO2-3) 的值：15.395233154296875
# 第16列 (CO2-4) 的值：1.7896991968154907
# 最后一列 (CO2 capacity) 的值：0.883749782878996
#
# 计算结果：0.883750
# ✓ 计算结果与Excel匹配
#
# 行号：105
# ------------------------------
# 第7列 (CO2-3) 的值：15.55744743347168
# 第16列 (CO2-4) 的值：1.8155757188796997
# 最后一列 (CO2 capacity) 的值：0.8832986113792994
#
# 计算结果：0.883299
# ✓ 计算结果与Excel匹配
#
# 行号：106
# ------------------------------
# 第7列 (CO2-3) 的值：15.770983695983887
# 第16列 (CO2-4) 的值：1.8341515064239502
# 最后一列 (CO2 capacity) 的值：0.8837008812017845
#
# 计算结果：0.883701
# ✓ 计算结果与Excel匹配
#
# 行号：107
# ------------------------------
# 第7列 (CO2-3) 的值：15.583457946777344
# 第16列 (CO2-4) 的值：1.845618724822998
# 最后一列 (CO2 capacity) 的值：0.8815655208794867
#
# 计算结果：0.881566
# ✓ 计算结果与Excel匹配
#
# 行号：108
# ------------------------------
# 第7列 (CO2-3) 的值：15.461385726928711
# 第16列 (CO2-4) 的值：1.8641854524612427
# 最后一列 (CO2 capacity) 的值：0.8794296005943091
#
# 计算结果：0.879430
# ✓ 计算结果与Excel匹配
#
# 行号：109
# ------------------------------
# 第7列 (CO2-3) 的值：15.297038078308105
# 第16列 (CO2-4) 的值：1.8343251943588257
# 最后一列 (CO2 capacity) 的值：0.8800862503598013
#
# 计算结果：0.880086
# ✓ 计算结果与Excel匹配
#
# 行号：110
# ------------------------------
# 第7列 (CO2-3) 的值：15.34345531463623
# 第16列 (CO2-4) 的值：1.834380030632019
# 最后一列 (CO2 capacity) 的值：0.88044544119849
#
# 计算结果：0.880445
# ✓ 计算结果与Excel匹配
#
# 行号：111
# ------------------------------
# 第7列 (CO2-3) 的值：15.187087059020996
# 第16列 (CO2-4) 的值：1.761757731437683
# 最后一列 (CO2 capacity) 的值：0.883996336849125
#
# 计算结果：0.883996
# ✓ 计算结果与Excel匹配
#
# 行号：112
# ------------------------------
# 第7列 (CO2-3) 的值：15.207341194152832
# 第16列 (CO2-4) 的值：1.743876338005066
# 最后一列 (CO2 capacity) 的值：0.885326677705135
#
# 计算结果：0.885327
# ✓ 计算结果与Excel匹配
#
# 行号：113
# ------------------------------
# 第7列 (CO2-3) 的值：15.300206184387207
# 第16列 (CO2-4) 的值：1.7558002471923828
# 最后一列 (CO2 capacity) 的值：0.8852433603813749
#
# 计算结果：0.885243
# ✓ 计算结果与Excel匹配
#
# 行号：114
# ------------------------------
# 第7列 (CO2-3) 的值：15.325972557067871
# 第16列 (CO2-4) 的值：1.7409249544143677
# 最后一列 (CO2 capacity) 的值：0.8864068855707623
#
# 计算结果：0.886407
# ✓ 计算结果与Excel匹配
#
# 行号：115
# ------------------------------
# 第7列 (CO2-3) 的值：15.31787109375
# 第16列 (CO2-4) 的值：1.7376264333724976
# 最后一列 (CO2 capacity) 的值：0.8865621454353743
#
# 计算结果：0.886562
# ✓ 计算结果与Excel匹配
#
# 行号：116
# ------------------------------
# 第7列 (CO2-3) 的值：15.395415306091309
# 第16列 (CO2-4) 的值：1.7367583513259888
# 最后一列 (CO2 capacity) 的值：0.8871898992787269
#
# 计算结果：0.887190
# ✓ 计算结果与Excel匹配
#
# 行号：117
# ------------------------------
# 第7列 (CO2-3) 的值：15.337546348571777
# 第16列 (CO2-4) 的值：1.7485636472702026
# 最后一列 (CO2 capacity) 的值：0.8859945647412484
#
# 计算结果：0.885995
# ✓ 计算结果与Excel匹配
#
# 行号：118
# ------------------------------
# 第7列 (CO2-3) 的值：15.479325294494629
# 第16列 (CO2-4) 的值：1.7464803457260132
# 最后一列 (CO2 capacity) 的值：0.8871733546198447
#
# 计算结果：0.887173
# ✓ 计算结果与Excel匹配
#
# 行号：119
# ------------------------------
# 第7列 (CO2-3) 的值：15.308611869812012
# 第16列 (CO2-4) 的值：1.759442925453186
# 最后一列 (CO2 capacity) 的值：0.8850684215906774
#
# 计算结果：0.885068
# ✓ 计算结果与Excel匹配
#
# 行号：120
# ------------------------------
# 第7列 (CO2-3) 的值：15.351434707641602
# 第16列 (CO2-4) 的值：1.7482165098190308
# 最后一列 (CO2 capacity) 的值：0.8861203175395191
#
# 计算结果：0.886120
# ✓ 计算结果与Excel匹配
#
# 行号：121
# ------------------------------
# 第7列 (CO2-3) 的值：14.972972869873047
# 第16列 (CO2-4) 的值：1.7362375259399414
# 最后一列 (CO2 capacity) 的值：0.8840418972885868
#
# 计算结果：0.884042
# ✓ 计算结果与Excel匹配
#
# 行号：122
# ------------------------------
# 第7列 (CO2-3) 的值：15.125852584838867
# 第16列 (CO2-4) 的值：1.6898216009140015
# 最后一列 (CO2 capacity) 的值：0.8882825552188863
#
# 计算结果：0.888283
# ✓ 计算结果与Excel匹配
#
# 行号：123
# ------------------------------
# 第7列 (CO2-3) 的值：14.85376262664795
# 第16列 (CO2-4) 的值：1.6461358070373535
# 最后一列 (CO2 capacity) 的值：0.8891771836932312
#
# 计算结果：0.889177
# ✓ 计算结果与Excel匹配
#
# 行号：124
# ------------------------------
# 第7列 (CO2-3) 的值：15.01984691619873
# 第16列 (CO2-4) 的值：1.6051647663116455
# 最后一列 (CO2 capacity) 的值：0.8931304176888452
#
# 计算结果：0.893130
# ✓ 计算结果与Excel匹配
#
# 行号：125
# ------------------------------
# 第7列 (CO2-3) 的值：15.115330696105957
# 第16列 (CO2-4) 的值：1.6121721267700195
# 最后一列 (CO2 capacity) 的值：0.8933419215773195
#
# 计算结果：0.893342
# ✓ 计算结果与Excel匹配
#
# 行号：126
# ------------------------------
# 第7列 (CO2-3) 的值：15.305139541625977
# 第16列 (CO2-4) 的值：1.5989148616790771
# 最后一列 (CO2 capacity) 的值：0.8955308537154825
#
# 计算结果：0.895531
# ✓ 计算结果与Excel匹配
#
# 行号：127
# ------------------------------
# 第7列 (CO2-3) 的值：15.450969696044922
# 第16列 (CO2-4) 的值：1.6332889795303345
# 最后一列 (CO2 capacity) 的值：0.8942921375382402
#
# 计算结果：0.894292
# ✓ 计算结果与Excel匹配
#
# 行号：128
# ------------------------------
# 第7列 (CO2-3) 的值：15.51830768585205
# 第16列 (CO2-4) 的值：1.6636227369308472
# 最后一列 (CO2 capacity) 的值：0.8927961237392166
#
# 计算结果：0.892796
# ✓ 计算结果与Excel匹配
#
# 行号：129
# ------------------------------
# 第7列 (CO2-3) 的值：15.461385726928711
# 第16列 (CO2-4) 的值：1.7190505266189575
# 最后一列 (CO2 capacity) 的值：0.8888165293214999
#
# 计算结果：0.888817
# ✓ 计算结果与Excel匹配
#
# 行号：130
# ------------------------------
# 第7列 (CO2-3) 的值：15.46890926361084
# 第16列 (CO2-4) 的值：1.7360639572143555
# 最后一列 (CO2 capacity) 的值：0.8877707582590659
#
# 计算结果：0.887771
# ✓ 计算结果与Excel匹配
#
# 行号：131
# ------------------------------
# 第7列 (CO2-3) 的值：15.492635726928711
# 第16列 (CO2-4) 的值：1.7308558225631714
# 最后一列 (CO2 capacity) 的值：0.8882788020662834
#
# 计算结果：0.888279
# ✓ 计算结果与Excel匹配
#
# 行号：132
# ------------------------------
# 第7列 (CO2-3) 的值：15.358379364013672
# 第16列 (CO2-4) 的值：1.7409249544143677
# 最后一列 (CO2 capacity) 的值：0.8866465716758148
#
# 计算结果：0.886647
# ✓ 计算结果与Excel匹配
#
# 行号：133
# ------------------------------
# 第7列 (CO2-3) 的值：15.28488540649414
# 第16列 (CO2-4) 的值：1.7282516956329346
# 最后一列 (CO2 capacity) 的值：0.8869306736903211
#
# 计算结果：0.886931
# ✓ 计算结果与Excel匹配
#
# 行号：134
# ------------------------------
# 第7列 (CO2-3) 的值：15.452127456665039
# 第16列 (CO2-4) 的值：1.698217749595642
# 最后一列 (CO2 capacity) 的值：0.8900981269823048
#
# 计算结果：0.890098
# ✓ 计算结果与Excel匹配
#
# 行号：135
# ------------------------------
# 第7列 (CO2-3) 的值：15.388471603393555
# 第16列 (CO2-4) 的值：1.715925693511963
# 最后一列 (CO2 capacity) 的值：0.8884927796771216
#
# 计算结果：0.888493
# ✓ 计算结果与Excel匹配
#
# 行号：136
# ------------------------------
# 第7列 (CO2-3) 的值：15.542980194091797
# 第16列 (CO2-4) 的值：1.719050645828247
# 最后一列 (CO2 capacity) 的值：0.8894001906737491
#
# 计算结果：0.889400
# ✓ 计算结果与Excel匹配
#
# 行号：137
# ------------------------------
# 第7列 (CO2-3) 的值：15.87919807434082
# 第16列 (CO2-4) 的值：1.7621049880981445
# 最后一列 (CO2 capacity) 的值：0.889030605963312
#
# 计算结果：0.889031
# ✓ 计算结果与Excel匹配
#
# 行号：138
# ------------------------------
# 第7列 (CO2-3) 的值：15.694018363952637
# 第16列 (CO2-4) 的值：1.835019588470459
# 最后一列 (CO2 capacity) 的值：0.8830752235714666
#
# 计算结果：0.883075
# ✓ 计算结果与Excel匹配
#
# 行号：139
# ------------------------------
# 第7列 (CO2-3) 的值：15.58290958404541
# 第16列 (CO2-4) 的值：1.8419638872146606
# 最后一列 (CO2 capacity) 的值：0.8817958945805244
#
# 计算结果：0.881796
# ✓ 计算结果与Excel匹配
#
# 行号：140
# ------------------------------
# 第7列 (CO2-3) 的值：15.363394737243652
# 第16列 (CO2-4) 的值：1.8328206539154053
# 最后一列 (CO2 capacity) 的值：0.8807021048888163
#
# 计算结果：0.880702
# ✓ 计算结果与Excel匹配
#
# 行号：141
# ------------------------------
# 第7列 (CO2-3) 的值：15.334074020385742
# 第16列 (CO2-4) 的值：1.7871042490005493
# 最后一列 (CO2 capacity) 的值：0.8834553526593976
#
# 计算结果：0.883455
# ✓ 计算结果与Excel匹配
#
# 行号：142
# ------------------------------
# 第7列 (CO2-3) 的值：15.291251182556152
# 第16列 (CO2-4) 的值：1.7529038190841675
# 最后一列 (CO2 capacity) 的值：0.8853655728915216
#
# 计算结果：0.885366
# ✓ 计算结果与Excel匹配
#
# 行号：143
# ------------------------------
# 第7列 (CO2-3) 的值：15.36784839630127
# 第16列 (CO2-4) 的值：1.761000156402588
# 最后一列 (CO2 capacity) 的值：0.885410103549276
#
# 计算结果：0.885410
# ✓ 计算结果与Excel匹配
#
# 行号：144
# ------------------------------
# 第7列 (CO2-3) 的值：15.483375549316406
# 第16列 (CO2-4) 的值：1.7388416528701782
# 最后一列 (CO2 capacity) 的值：0.8876962166724072
#
# 计算结果：0.887696
# ✓ 计算结果与Excel匹配
#
# 行号：145
# ------------------------------
# 第7列 (CO2-3) 的值：15.422614097595215
# 第16列 (CO2-4) 的值：1.7650562524795532
# 最后一列 (CO2 capacity) 的值：0.8855540155961776
#
# 计算结果：0.885554
# ✓ 计算结果与Excel匹配
#
# 行号：146
# ------------------------------
# 第7列 (CO2-3) 的值：15.226859092712402
# 第16列 (CO2-4) 的值：1.775046467781067
# 最后一列 (CO2 capacity) 的值：0.8834266175989894
#
# 计算结果：0.883427
# ✓ 计算结果与Excel匹配
#
# 行号：147
# ------------------------------
# 第7列 (CO2-3) 的值：15.089868545532227
# 第16列 (CO2-4) 的值：1.7312029600143433
# 最后一列 (CO2 capacity) 的值：0.8852738209885258
#
# 计算结果：0.885274
# ✓ 计算结果与Excel匹配
#
# 行号：148
# ------------------------------
# 第7列 (CO2-3) 的值：15.180721282958984
# 第16列 (CO2-4) 的值：1.680336356163025
# 最后一列 (CO2 capacity) 的值：0.8893111648094564
#
# 计算结果：0.889311
# ✓ 计算结果与Excel匹配
#
# 行号：149
# ------------------------------
# 第7列 (CO2-3) 的值：15.198451042175293
# 第16列 (CO2-4) 的值：1.6801942586898804
# 最后一列 (CO2 capacity) 的值：0.889449638385689
#
# 计算结果：0.889450
# ✓ 计算结果与Excel匹配
#
# 行号：150
# ------------------------------
# 第7列 (CO2-3) 的值：15.277362823486328
# 第16列 (CO2-4) 的值：1.6520384550094604
# 最后一列 (CO2 capacity) 的值：0.8918636368006044
#
# 计算结果：0.891864
# ✓ 计算结果与Excel匹配
#
# 行号：151
# ------------------------------
# 第7列 (CO2-3) 的值：15.277362823486328
# 第16列 (CO2-4) 的值：1.635372281074524
# 最后一列 (CO2 capacity) 的值：0.8929545432697049
#
# 计算结果：0.892955
# ✓ 计算结果与Excel匹配
#
# 行号：152
# ------------------------------
# 第7列 (CO2-3) 的值：15.140582084655762
# 第16列 (CO2-4) 的值：1.6475247144699097
# 最后一列 (CO2 capacity) 的值：0.8911848497463255
#
# 计算结果：0.891185
# ✓ 计算结果与Excel匹配
#
# 行号：153
# ------------------------------
# 第7列 (CO2-3) 的值：15.107229232788086
# 第16列 (CO2-4) 的值：1.6298168897628784
# 最后一列 (CO2 capacity) 的值：0.8921167565111415
#
# 计算结果：0.892117
# ✓ 计算结果与Excel匹配
#
# 行号：154
# ------------------------------
# 第7列 (CO2-3) 的值：14.948668479919434
# 第16列 (CO2-4) 的值：1.618532419204712
# 最后一列 (CO2 capacity) 的值：0.8917273186318307
#
# 计算结果：0.891727
# ✓ 计算结果与Excel匹配
#
# 行号：155
# ------------------------------
# 第7列 (CO2-3) 的值：15.118487358093262
# 第16列 (CO2-4) 的值：1.5982836484909058
# 最后一列 (CO2 capacity) 的值：0.8942828332865385
#
# 计算结果：0.894283
# ✓ 计算结果与Excel匹配
#
# 行号：156
# ------------------------------
# 第7列 (CO2-3) 的值：15.1326904296875
# 第16列 (CO2-4) 的值：1.5864152908325195
# 最后一列 (CO2 capacity) 的值：0.8951663421515403
#
# 计算结果：0.895166
# ✓ 计算结果与Excel匹配
#
# 行号：157
# ------------------------------
# 第7列 (CO2-3) 的值：15.066142082214355
# 第16列 (CO2-4) 的值：1.571485161781311
# 最后一列 (CO2 capacity) 的值：0.8956942558217039
#
# 计算结果：0.895694
# ✓ 计算结果与Excel匹配
#
# 行号：158
# ------------------------------
# 第7列 (CO2-3) 的值：14.990649223327637
# 第16列 (CO2-4) 的值：1.5671923160552979
# 最后一列 (CO2 capacity) 的值：0.8954553406788734
#
# 计算结果：0.895455
# ✓ 计算结果与Excel匹配
#
# 行号：159
# ------------------------------
# 第7列 (CO2-3) 的值：15.072507858276367
# 第16列 (CO2-4) 的值：1.5541244745254517
# 最后一列 (CO2 capacity) 的值：0.8968901201353777
#
# 计算结果：0.896890
# ✓ 计算结果与Excel匹配
#
# 行号：160
# ------------------------------
# 第7列 (CO2-3) 的值：15.11938190460205
# 第16列 (CO2-4) 的值：1.559853434562683
# 最后一列 (CO2 capacity) 的值：0.896830872822394
#
# 计算结果：0.896831
# ✓ 计算结果与Excel匹配
#
# 行号：161
# ------------------------------
# 第7列 (CO2-3) 的值：15.140055656433105
# 第16列 (CO2-4) 的值：1.5581963062286377
# 最后一列 (CO2 capacity) 的值：0.897081203557759
#
# 计算结果：0.897081
# ✓ 计算结果与Excel匹配
#
# 行号：162
# ------------------------------
# 第7列 (CO2-3) 的值：15.303982734680176
# 第16列 (CO2-4) 的值：1.5700962543487549
# 最后一列 (CO2 capacity) 的值：0.8974060359601179
#
# 计算结果：0.897406
# ✓ 计算结果与Excel匹配
#
# 行号：163
# ------------------------------
# 第7列 (CO2-3) 的值：15.25074291229248
# 第16列 (CO2-4) 的值：1.6072479486465454
# 最后一列 (CO2 capacity) 的值：0.8946118259359639
#
# 计算结果：0.894612
# ✓ 计算结果与Excel匹配
#
# 行号：164
# ------------------------------
# 第7列 (CO2-3) 的值：15.295775413513184
# 第16列 (CO2-4) 的值：1.611856460571289
# 最后一列 (CO2 capacity) 的值：0.8946208075762356
#
# 计算结果：0.894621
# ✓ 计算结果与Excel匹配
#
# 行号：165
# ------------------------------
# 第7列 (CO2-3) 的值：15.334074020385742
# 第16列 (CO2-4) 的值：1.6565521955490112
# 最后一列 (CO2 capacity) 的值：0.8919692057474926
#
# 计算结果：0.891969
# ✓ 计算结果与Excel匹配
#
# 行号：166
# ------------------------------
# 第7列 (CO2-3) 的值：15.449234008789062
# 第16列 (CO2-4) 的值：1.666621446609497
# 最后一列 (CO2 capacity) 的值：0.8921227132904223
#
# 计算结果：0.892123
# ✓ 计算结果与Excel匹配
#
# 行号：167
# ------------------------------
# 第7列 (CO2-3) 的值：15.30261516571045
# 第16列 (CO2-4) 的值：1.671040415763855
# 最后一列 (CO2 capacity) 的值：0.8908003372189439
#
# 计算结果：0.890800
# ✓ 计算结果与Excel匹配
#
# 行号：168
# ------------------------------
# 第7列 (CO2-3) 的值：15.196346282958984
# 第16列 (CO2-4) 的值：1.6718297004699707
# 最后一列 (CO2 capacity) 的值：0.8899847588795248
#
# 计算结果：0.889985
# ✓ 计算结果与Excel匹配
#
# 行号：169
# ------------------------------
# 第7列 (CO2-3) 的值：15.404674530029297
# 第16列 (CO2-4) 的值：1.6518648862838745
# 最后一列 (CO2 capacity) 的值：0.8927685954634231
#
# 计算结果：0.892769
# ✓ 计算结果与Excel匹配
#
# 行号：170
# ------------------------------
# 第7列 (CO2-3) 的值：15.509889602661133
# 第16列 (CO2-4) 的值：1.6674106121063232
# 最后一列 (CO2 capacity) 的值：0.8924937149894198
#
# 计算结果：0.892494
# ✓ 计算结果与Excel匹配
#
# 行号：171
# ------------------------------
# 第7列 (CO2-3) 的值：15.389628410339355
# 第16列 (CO2-4) 的值：1.6996066570281982
# 最后一列 (CO2 capacity) 的值：0.8895615532934937
#
# 计算结果：0.889562
# ✓ 计算结果与Excel匹配
#
# 行号：172
# ------------------------------
# 第7列 (CO2-3) 的值：15.361272811889648
# 第16列 (CO2-4) 的值：1.6996066570281982
# 最后一列 (CO2 capacity) 的值：0.8893576933473443
#
# 计算结果：0.889358
# ✓ 计算结果与Excel匹配
#
# 行号：173
# ------------------------------
# 第7列 (CO2-3) 的值：15.5430326461792
# 第16列 (CO2-4) 的值：1.687454104423523
# 最后一列 (CO2 capacity) 的值：0.8914334066693005
#
# 计算结果：0.891433
# ✓ 计算结果与Excel匹配
#
# 行号：174
# ------------------------------
# 第7列 (CO2-3) 的值：15.280835151672363
# 第16列 (CO2-4) 的值：1.7273836135864258
# 最后一列 (CO2 capacity) 的值：0.8869575126986841
#
# 计算结果：0.886958
# ✓ 计算结果与Excel匹配
#
# 行号：175
# ------------------------------
# 第7列 (CO2-3) 的值：15.47006607055664
# 第16列 (CO2-4) 的值：1.71193265914917
# 最后一列 (CO2 capacity) 的值：0.8893390208327939
#
# 计算结果：0.889339
# ✓ 计算结果与Excel匹配
#
# 行号：176
# ------------------------------
# 第7列 (CO2-3) 的值：15.442026138305664
# 第16列 (CO2-4) 的值：1.7122324705123901
# 最后一列 (CO2 capacity) 的值：0.8891186651818308
#
# 计算结果：0.889119
# ✓ 计算结果与Excel匹配
#
# 行号：177
# ------------------------------
# 第7列 (CO2-3) 的值：15.178985595703125
# 第16列 (CO2-4) 的值：1.7124534845352173
# 最后一列 (CO2 capacity) 的值：0.8871826135061371
#
# 计算结果：0.887183
# ✓ 计算结果与Excel匹配
#
# 行号：178
# ------------------------------
# 第7列 (CO2-3) 的值：15.308611869812012
# 第16列 (CO2-4) 的值：1.6850236654281616
# 最后一列 (CO2 capacity) 的值：0.8899296892652323
#
# 计算结果：0.889930
# ✓ 计算结果与Excel匹配
#
# 行号：179
# ------------------------------
# 第7列 (CO2-3) 的值：15.41677474975586
# 第16列 (CO2-4) 的值：1.6893479824066162
# 最后一列 (CO2 capacity) 的值：0.890421439644283
#
# 计算结果：0.890421
# ✓ 计算结果与Excel匹配
#
# 行号：180
# ------------------------------
# 第7列 (CO2-3) 的值：15.359537124633789
# 第16列 (CO2-4) 的值：1.6978704929351807
# 最后一列 (CO2 capacity) 的值：0.8894582252604398
#
# 计算结果：0.889458
# ✓ 计算结果与Excel匹配
#
# 行号：181
# ------------------------------
# 第7列 (CO2-3) 的值：15.31908893585205
# 第16列 (CO2-4) 的值：1.6849870681762695
# 最后一列 (CO2 capacity) 的值：0.8900073577983605
#
# 计算结果：0.890007
# ✓ 计算结果与Excel匹配
#
# 行号：182
# ------------------------------
# 第7列 (CO2-3) 的值：15.363639831542969
# 第16列 (CO2-4) 的值：1.6986596584320068
# 最后一列 (CO2 capacity) 的值：0.8894363785497951
#
# 计算结果：0.889436
# ✓ 计算结果与Excel匹配
#
# 行号：183
# ------------------------------
# 第7列 (CO2-3) 的值：15.433222770690918
# 第16列 (CO2-4) 的值：1.711759090423584
# 最后一列 (CO2 capacity) 的值：0.8890860894152083
#
# 计算结果：0.889086
# ✓ 计算结果与Excel匹配
#
# 行号：184
# ------------------------------
# 第7列 (CO2-3) 的值：15.375740051269531
# 第16列 (CO2-4) 的值：1.7002462148666382
# 最后一列 (CO2 capacity) 的值：0.8894202029172408
#
# 计算结果：0.889420
# ✓ 计算结果与Excel匹配
#
# 行号：185
# ------------------------------
# 第7列 (CO2-3) 的值：15.319975852966309
# 第16列 (CO2-4) 的值：1.75358247756958
# 最后一列 (CO2 capacity) 的值：0.8855362113883459
#
# 计算结果：0.885536
# ✓ 计算结果与Excel匹配
#
# 行号：186
# ------------------------------
# 第7列 (CO2-3) 的值：15.360511779785156
# 第16列 (CO2-4) 的值：1.731860876083374
# 最后一列 (CO2 capacity) 的值：0.8872523975169533
#
# 计算结果：0.887252
# ✓ 计算结果与Excel匹配
#
# 行号：187
# ------------------------------
# 第7列 (CO2-3) 的值：15.573102951049805
# 第16列 (CO2-4) 的值：1.718886137008667
# 最后一列 (CO2 capacity) 的值：0.8896246854328543
#
# 计算结果：0.889625
# ✓ 计算结果与Excel匹配
#
# 行号：188
# ------------------------------
# 第7列 (CO2-3) 的值：15.320501327514648
# 第16列 (CO2-4) 的值：1.7262789011001587
# 最后一列 (CO2 capacity) 的值：0.8873222968232853
#
# 计算结果：0.887322
# ✓ 计算结果与Excel匹配
#
# 行号：189
# ------------------------------
# 第7列 (CO2-3) 的值：15.353201866149902
# 第16列 (CO2-4) 的值：1.725830316543579
# 最后一列 (CO2 capacity) 的值：0.887591504912821
#
# 计算结果：0.887592
# ✓ 计算结果与Excel匹配
#
# 行号：190
# ------------------------------
# 第7列 (CO2-3) 的值：15.243250846862793
# 第16列 (CO2-4) 的值：1.7271095514297485
# 最后一列 (CO2 capacity) 的值：0.8866967703424493
#
# 计算结果：0.886697
# ✓ 计算结果与Excel匹配
#
# 行号：191
# ------------------------------
# 第7列 (CO2-3) 的值：15.412566184997559
# 第16列 (CO2-4) 的值：1.7463226318359375
# 最后一列 (CO2 capacity) 的值：0.8866948818986554
#
# 计算结果：0.886695
# ✓ 计算结果与Excel匹配
#
# 行号：192
# ------------------------------
# 第7列 (CO2-3) 的值：15.445487022399902
# 第16列 (CO2-4) 的值：1.7392619848251343
# 最后一列 (CO2 capacity) 的值：0.8873935161576478
#
# 计算结果：0.887394
# ✓ 计算结果与Excel匹配
#
# 行号：193
# ------------------------------
# 第7列 (CO2-3) 的值：15.448533058166504
# 第16列 (CO2-4) 的值：1.7291196584701538
# 最后一列 (CO2 capacity) 的值：0.8880722427197646
#
# 计算结果：0.888072
# ✓ 计算结果与Excel匹配
#
# 行号：194
# ------------------------------
# 第7列 (CO2-3) 的值：15.575650215148926
# 第16列 (CO2-4) 的值：1.7474273443222046
# 最后一列 (CO2 capacity) 的值：0.8878103115963242
#
# 计算结果：0.887810
# ✓ 计算结果与Excel匹配
#
# 行号：195
# ------------------------------
# 第7列 (CO2-3) 的值：15.461020469665527
# 第16列 (CO2-4) 的值：1.7677700519561768
# 最后一列 (CO2 capacity) 的值：0.885662783033983
#
# 计算结果：0.885663
# ✓ 计算结果与Excel匹配
#
# 行号：196
# ------------------------------
# 第7列 (CO2-3) 的值：15.334318161010742
# 第16列 (CO2-4) 的值：1.762013554573059
# 最后一列 (CO2 capacity) 的值：0.8850934527331525
#
# 计算结果：0.885093
# ✓ 计算结果与Excel匹配
#
# 行号：197
# ------------------------------
# 第7列 (CO2-3) 的值：15.457808494567871
# 第16列 (CO2-4) 的值：1.7756778001785278
# 最后一列 (CO2 capacity) 的值：0.8851274551109538
#
# 计算结果：0.885127
# ✓ 计算结果与Excel匹配
#
# 行号：198
# ------------------------------
# 第7列 (CO2-3) 的值：15.487822532653809
# 第16列 (CO2-4) 的值：1.7831203937530518
# 最后一列 (CO2 capacity) 的值：0.8848695231370579
#
# 计算结果：0.884870
# ✓ 计算结果与Excel匹配
#
# 行号：199
# ------------------------------
# 第7列 (CO2-3) 的值：15.485386848449707
# 第16列 (CO2-4) 的值：1.7822980880737305
# 最后一列 (CO2 capacity) 的值：0.8849045163988162
#
# 计算结果：0.884905
# ✓ 计算结果与Excel匹配
#
# 行号：200
# ------------------------------
# 第7列 (CO2-3) 的值：15.489899635314941
# 第16列 (CO2-4) 的值：1.7723634243011475
# 最后一列 (CO2 capacity) 的值：0.8855794120021029
#
# 计算结果：0.885579
# ✓ 计算结果与Excel匹配
#
# 行号：201
# ------------------------------
# 第7列 (CO2-3) 的值：15.577062606811523
# 第16列 (CO2-4) 的值：1.7722471952438354
# 最后一列 (CO2 capacity) 的值：0.8862271251019516
#
# 计算结果：0.886227
# ✓ 计算结果与Excel匹配
#
# 行号：202
# ------------------------------
# 第7列 (CO2-3) 的值：15.433609008789062
# 第16列 (CO2-4) 的值：1.772704005241394
# 最后一列 (CO2 capacity) 的值：0.885140021090862
#
# 计算结果：0.885140
# ✓ 计算结果与Excel匹配
#
# 行号：203
# ------------------------------
# 第7列 (CO2-3) 的值：15.632467269897461
# 第16列 (CO2-4) 的值：1.7938275337219238
# 最后一列 (CO2 capacity) 的值：0.8852498775304527
#
# 计算结果：0.885250
# ✓ 计算结果与Excel匹配
#
# 行号：204
# ------------------------------
# 第7列 (CO2-3) 的值：15.578889846801758
# 第16列 (CO2-4) 的值：1.8022171258926392
# 最后一列 (CO2 capacity) 的值：0.8843167168126154
#
# 计算结果：0.884317
# ✓ 计算结果与Excel匹配
#
# 行号：205
# ------------------------------
# 第7列 (CO2-3) 的值：15.42782211303711
# 第16列 (CO2-4) 的值：1.8124507665634155
# 最后一列 (CO2 capacity) 的值：0.8825206336134882
#
# 计算结果：0.882521
# ✓ 计算结果与Excel匹配
#
# 行号：206
# ------------------------------
# 第7列 (CO2-3) 的值：15.445708274841309
# 第16列 (CO2-4) 的值：1.8056644201278687
# 最后一列 (CO2 capacity) 的值：0.8830960427325292
#
# 计算结果：0.883096
# ✓ 计算结果与Excel匹配
#
# 行号：207
# ------------------------------
# 第7列 (CO2-3) 的值：15.48965072631836
# 第16列 (CO2-4) 的值：1.7971917390823364
# 最后一列 (CO2 capacity) 的值：0.8839746763283216
#
# 计算结果：0.883975
# ✓ 计算结果与Excel匹配
#
# 行号：208
# ------------------------------
# 第7列 (CO2-3) 的值：15.457060813903809
# 第16列 (CO2-4) 的值：1.811171531677246
# 最后一列 (CO2 capacity) 的值：0.8828256190822464
#
# 计算结果：0.882826
# ✓ 计算结果与Excel匹配
#
# 行号：209
# ------------------------------
# 第7列 (CO2-3) 的值：15.383262634277344
# 第16列 (CO2-4) 的值：1.8251240253448486
# 最后一列 (CO2 capacity) 的值：0.8813565061758704
#
# 计算结果：0.881357
# ✓ 计算结果与Excel匹配
#
# 行号：210
# ------------------------------
# 第7列 (CO2-3) 的值：15.468330383300781
# 第16列 (CO2-4) 的值：1.7992018461227417
# 最后一列 (CO2 capacity) 的值：0.8836848062112046
#
# 计算结果：0.883685
# ✓ 计算结果与Excel匹配
#
# 行号：211
# ------------------------------
# 第7列 (CO2-3) 的值：15.713815689086914
# 第16列 (CO2-4) 的值：1.7960039377212524
# 最后一列 (CO2 capacity) 的值：0.8857054216966183
#
# 计算结果：0.885705
# ✓ 计算结果与Excel匹配
#
# 行号：212
# ------------------------------
# 第7列 (CO2-3) 的值：15.69806957244873
# 第16列 (CO2-4) 的值：1.86470627784729
# 最后一列 (CO2 capacity) 的值：0.8812142939460539
#
# 计算结果：0.881214
# ✓ 计算结果与Excel匹配
#
# 行号：213
# ------------------------------
# 第7列 (CO2-3) 的值：15.570666313171387
# 第16列 (CO2-4) 的值：1.8426034450531006
# 最后一列 (CO2 capacity) 的值：0.8816618757352456
#
# 计算结果：0.881662
# ✓ 计算结果与Excel匹配
#
# 行号：214
# ------------------------------
# 第7列 (CO2-3) 的值：15.68051528930664
# 第16列 (CO2-4) 的值：1.8213239908218384
# 最后一列 (CO2 capacity) 的值：0.8838479503244454
#
# 计算结果：0.883848
# ✓ 计算结果与Excel匹配
#
# 行号：215
# ------------------------------
# 第7列 (CO2-3) 的值：15.369953155517578
# 第16列 (CO2-4) 的值：1.8004720211029053
# 最后一列 (CO2 capacity) 的值：0.8828576767355623
#
# 计算结果：0.882858
# ✓ 计算结果与Excel匹配
#
# 行号：216
# ------------------------------
# 第7列 (CO2-3) 的值：15.239900588989258
# 第16列 (CO2-4) 的值：1.8109887838363647
# 最后一列 (CO2 capacity) 的值：0.8811679398260122
#
# 计算结果：0.881168
# ✓ 计算结果与Excel匹配
#
# 行号：217
# ------------------------------
# 第7列 (CO2-3) 的值：15.216022491455078
# 第16列 (CO2-4) 的值：1.7079397439956665
# 最后一列 (CO2 capacity) 的值：0.8877538630772397
#
# 计算结果：0.887754
# ✓ 计算结果与Excel匹配
#
# 行号：218
# ------------------------------
# 第7列 (CO2-3) 的值：15.231646537780762
# 第16列 (CO2-4) 的值：1.6940511465072632
# 最后一列 (CO2 capacity) 的值：0.888780826005559
#
# 计算结果：0.888781
# ✓ 计算结果与Excel匹配
#
# 行号：219
# ------------------------------
# 第7列 (CO2-3) 的值：15.112589836120605
# 第16列 (CO2-4) 的值：1.7181551456451416
# 最后一列 (CO2 capacity) 的值：0.8863096819091472
#
# 计算结果：0.886310
# ✓ 计算结果与Excel匹配
#
# 行号：220
# ------------------------------
# 第7列 (CO2-3) 的值：15.02852725982666
# 第16列 (CO2-4) 的值：1.6874542236328125
# 最后一列 (CO2 capacity) 的值：0.8877165942837518
#
# 计算结果：0.887717
# ✓ 计算结果与Excel匹配
#
# 行号：221
# ------------------------------
# 第7列 (CO2-3) 的值：15.274469375610352
# 第16列 (CO2-4) 的值：1.6603715419769287
# 最后一列 (CO2 capacity) 的值：0.8912975959329794
#
# 计算结果：0.891298
# ✓ 计算结果与Excel匹配
#
# 行号：222
# ------------------------------
# 第7列 (CO2-3) 的值：15.23045825958252
# 第16列 (CO2-4) 的值：1.6742966175079346
# 最后一列 (CO2 capacity) 的值：0.8900691897136765
#
# 计算结果：0.890069
# ✓ 计算结果与Excel匹配
#
# 行号：223
# ------------------------------
# 第7列 (CO2-3) 的值：15.302824974060059
# 第16列 (CO2-4) 的值：1.6638437509536743
# 最后一列 (CO2 capacity) 的值：0.8912721178100077
#
# 计算结果：0.891272
# ✓ 计算结果与Excel匹配
#
# 行号：224
# ------------------------------
# 第7列 (CO2-3) 的值：15.122274398803711
# 第16列 (CO2-4) 的值：1.6737393140792847
# 最后一列 (CO2 capacity) 的值：0.8893196043174768
#
# 计算结果：0.889320
# ✓ 计算结果与Excel匹配
#
# 行号：225
# ------------------------------
# 第7列 (CO2-3) 的值：15.16702651977539
# 第16列 (CO2-4) 的值：1.6603715419769287
# 最后一列 (CO2 capacity) 的值：0.8905275506829194
#
# 计算结果：0.890528
# ✓ 计算结果与Excel匹配
#
# 行号：226
# ------------------------------
# 第7列 (CO2-3) 的值：15.000750541687012
# 第16列 (CO2-4) 的值：1.6454414129257202
# 最后一列 (CO2 capacity) 的值：0.8903093942964356
#
# 计算结果：0.890309
# ✓ 计算结果与Excel匹配
#
# 行号：227
# ------------------------------
# 第7列 (CO2-3) 的值：14.909895896911621
# 第16列 (CO2-4) 的值：1.601345419883728
# 最后一列 (CO2 capacity) 的值：0.8925984841909309
#
# 计算结果：0.892598
# ✓ 计算结果与Excel匹配
#
# 行号：228
# ------------------------------
# 第7列 (CO2-3) 的值：14.991175651550293
# 第16列 (CO2-4) 的值：1.5719480514526367
# 最后一列 (CO2 capacity) 的值：0.8951417762028506
#
# 计算结果：0.895142
# ✓ 计算结果与Excel匹配
#
# 行号：229
# ------------------------------
# 第7列 (CO2-3) 的值：14.940566062927246
# 第16列 (CO2-4) 的值：1.5603742599487305
# 最后一列 (CO2 capacity) 的值：0.8955612355397589
#
# 计算结果：0.895561
# ✓ 计算结果与Excel匹配
#
# 行号：230
# ------------------------------
# 第7列 (CO2-3) 的值：14.913947105407715
# 第16列 (CO2-4) 的值：1.5442289113998413
# 最后一列 (CO2 capacity) 的值：0.8964573965238275
#
# 计算结果：0.896457
# ✓ 计算结果与Excel匹配
#
# 行号：231
# ------------------------------
# 第7列 (CO2-3) 的值：15.20739459991455
# 第16列 (CO2-4) 的值：1.5390995740890503
# 最后一列 (CO2 capacity) 的值：0.8987926850995437
#
# 计算结果：0.898793
# ✓ 计算结果与Excel匹配
#
# 行号：232
# ------------------------------
# 第7列 (CO2-3) 的值：15.227595329284668
# 第16列 (CO2-4) 的值：1.5569021701812744
# 最后一列 (CO2 capacity) 的值：0.8977578444583993
#
# 计算结果：0.897758
# ✓ 计算结果与Excel匹配
#
# 行号：233
# ------------------------------
# 第7列 (CO2-3) 的值：15.195188522338867
# 第16列 (CO2-4) 的值：1.579297423362732
# 最后一列 (CO2 capacity) 的值：0.8960659539668782
#
# 计算结果：0.896066
# ✓ 计算结果与Excel匹配
#
# 行号：234
# ------------------------------
# 第7列 (CO2-3) 的值：15.177407264709473
# 第16列 (CO2-4) 的值：1.5790292024612427
# 最后一列 (CO2 capacity) 的值：0.8959618612770046
#
# 计算结果：0.895962
# ✓ 计算结果与Excel匹配
#
# 行号：235
# ------------------------------
# 第7列 (CO2-3) 的值：15.087553977966309
# 第16列 (CO2-4) 的值：1.5777349472045898
# 最后一列 (CO2 capacity) 的值：0.8954280495361477
#
# 计算结果：0.895428
# ✓ 计算结果与Excel匹配
#
# 行号：236
# ------------------------------
# 第7列 (CO2-3) 的值：15.239169120788574
# 第16列 (CO2-4) 的值：1.56245756149292
# 最后一列 (CO2 capacity) 的值：0.8974709481134712
#
# 计算结果：0.897471
# ✓ 计算结果与Excel匹配
#
# 行号：237
# ------------------------------
# 第7列 (CO2-3) 的值：15.125326156616211
# 第16列 (CO2-4) 的值：1.5733474493026733
# 最后一列 (CO2 capacity) 的值：0.8959792712559491
#
# 计算结果：0.895979
# ✓ 计算结果与Excel匹配
#
# 行号：238
# ------------------------------
# 第7列 (CO2-3) 的值：15.278520584106445
# 第16列 (CO2-4) 的值：1.562110424041748
# 最后一列 (CO2 capacity) 的值：0.8977577432682362
#
# 计算结果：0.897758
# ✓ 计算结果与Excel匹配
#
# 行号：239
# ------------------------------
# 第7列 (CO2-3) 的值：15.520411491394043
# 第16列 (CO2-4) 的值：1.5891929864883423
# 最后一列 (CO2 capacity) 的值：0.8976062595138319
#
# 计算结果：0.897606
# ✓ 计算结果与Excel匹配
#
# 行号：240
# ------------------------------
# 第7列 (CO2-3) 的值：15.494633674621582
# 第16列 (CO2-4) 的值：1.6293749809265137
# 最后一列 (CO2 capacity) 的值：0.894842626476853
#
# 计算结果：0.894843
# ✓ 计算结果与Excel匹配
#
# 行号：241
# ------------------------------
# 第7列 (CO2-3) 的值：15.588696479797363
# 第16列 (CO2-4) 的值：1.7072453498840332
# 最后一列 (CO2 capacity) 的值：0.8904818403452406
#
# 计算结果：0.890482
# ✓ 计算结果与Excel匹配
#
# 行号：242
# ------------------------------
# 第7列 (CO2-3) 的值：15.6245756149292
# 第16列 (CO2-4) 的值：1.7461332082748413
# 最后一列 (CO2 capacity) 的值：0.8882444393173521
#
# 计算结果：0.888244
# ✓ 计算结果与Excel匹配
#
# 行号：243
# ------------------------------
# 第7列 (CO2-3) 的值：15.452021598815918
# 第16列 (CO2-4) 的值：1.7389048337936401
# 最后一列 (CO2 capacity) 的值：0.8874642503782876
#
# 计算结果：0.887464
# ✓ 计算结果与Excel匹配
#
# 行号：244
# ------------------------------
# 第7列 (CO2-3) 的值：15.284307479858398
# 第16列 (CO2-4) 的值：1.7582855224609375
# 最后一列 (CO2 capacity) 的值：0.8849613876992465
#
# 计算结果：0.884961
# ✓ 计算结果与Excel匹配
#
# 行号：245
# ------------------------------
# 第7列 (CO2-3) 的值：15.605387687683105
# 第16列 (CO2-4) 的值：1.745658040046692
# 最后一列 (CO2 capacity) 的值：0.8881374769417302
#
# 计算结果：0.888137
# ✓ 计算结果与Excel匹配
#
# 行号：246
# ------------------------------
# 第7列 (CO2-3) 的值：15.091131210327148
# 第16列 (CO2-4) 的值：1.683666467666626
# 最后一列 (CO2 capacity) 的值：0.8884333822162741
#
# 计算结果：0.888433
# ✓ 计算结果与Excel匹配
#
# 行号：247
# ------------------------------
# 第7列 (CO2-3) 的值：15.272733688354492
# 第16列 (CO2-4) 的值：1.6211365461349487
# 最后一列 (CO2 capacity) 的值：0.8938541993061091
#
# 计算结果：0.893854
# ✓ 计算结果与Excel匹配
#
# 行号：248
# ------------------------------
# 第7列 (CO2-3) 的值：15.039491653442383
# 第16列 (CO2-4) 的值：1.7136778831481934
# 最后一列 (CO2 capacity) 的值：0.8860548000798983
#
# 计算结果：0.886055
# ✓ 计算结果与Excel匹配
#
# 行号：249
# ------------------------------
# 第7列 (CO2-3) 的值：15.329971313476562
# 第16列 (CO2-4) 的值：1.682130217552185
# 最后一列 (CO2 capacity) 的值：0.890271796133537
#
# 计算结果：0.890272
# ✓ 计算结果与Excel匹配
#
# 行号：250
# ------------------------------
# 第7列 (CO2-3) 的值：15.31092643737793
# 第16列 (CO2-4) 的值：1.7114118337631226
# 最后一列 (CO2 capacity) 的值：0.8882228426370645
#
# 计算结果：0.888223
# ✓ 计算结果与Excel匹配
#
# 行号：251
# ------------------------------
# 第7列 (CO2-3) 的值：15.430136680603027
# 第16列 (CO2-4) 的值：1.708287000656128
# 最后一列 (CO2 capacity) 的值：0.8892889262086974
#
# 计算结果：0.889289
# ✓ 计算结果与Excel匹配
#
# 行号：252
# ------------------------------
# 第7列 (CO2-3) 的值：15.375740051269531
# 第16列 (CO2-4) 的值：1.7127060890197754
# 最后一列 (CO2 capacity) 的值：0.8886098436036994
#
# 计算结果：0.888610
# ✓ 计算结果与Excel匹配
#
# 行号：253
# ------------------------------
# 第7列 (CO2-3) 的值：15.178986549377441
# 第16列 (CO2-4) 的值：1.6996066570281982
# 最后一列 (CO2 capacity) 的值：0.8880289766711792
#
# 计算结果：0.888029
# ✓ 计算结果与Excel匹配
#
# 行号：254
# ------------------------------
# 第7列 (CO2-3) 的值：14.990333557128906
# 第16列 (CO2-4) 的值：1.6787738800048828
# 最后一列 (CO2 capacity) 的值：0.8880095713943261
#
# 计算结果：0.888010
# ✓ 计算结果与Excel匹配
#
# 行号：255
# ------------------------------
# 第7列 (CO2-3) 的值：14.956979751586914
# 第16列 (CO2-4) 的值：1.6421587467193604
# 最后一列 (CO2 capacity) 的值：0.8902078645560024
#
# 计算结果：0.890208
# ✓ 计算结果与Excel匹配
#
# 行号：256
# ------------------------------
# 第7列 (CO2-3) 的值：14.721822738647461
# 第16列 (CO2-4) 的值：1.5690546035766602
# 最后一列 (CO2 capacity) 的值：0.8934198141472247
#
# 计算结果：0.893420
# ✓ 计算结果与Excel匹配
#
# 行号：257
# ------------------------------
# 第7列 (CO2-3) 的值：14.9465970993042
# 第16列 (CO2-4) 的值：1.6710072755813599
# 最后一列 (CO2 capacity) 的值：0.8882014906483865
#
# 计算结果：0.888201
# ✓ 计算结果与Excel匹配
#
# 行号：258
# ------------------------------
# 第7列 (CO2-3) 的值：14.75023078918457
# 第16列 (CO2-4) 的值：1.555039882659912
# 最后一列 (CO2 capacity) 的值：0.8945752168298189
#
# 计算结果：0.894575
# ✓ 计算结果与Excel匹配
#
# 行号：259
# ------------------------------
# 第7列 (CO2-3) 的值：14.721822738647461
# 第16列 (CO2-4) 的值：1.537805438041687
# 最后一列 (CO2 capacity) 的值：0.8955424565733516
#
# 计算结果：0.895542
# ✓ 计算结果与Excel匹配
#
# 行号：260
# ------------------------------
# 第7列 (CO2-3) 的值：14.721822738647461
# 第16列 (CO2-4) 的值：1.5212489366531372
# 最后一列 (CO2 capacity) 的值：0.8966670796368453
#
# 计算结果：0.896667
# ✓ 计算结果与Excel匹配
#
# 行号：261
# ------------------------------
# 第7列 (CO2-3) 的值：14.721822738647461
# 第16列 (CO2-4) 的值：1.6186429262161255
# 最后一列 (CO2 capacity) 的值：0.8900514593232471
#
# 计算结果：0.890051
# ✓ 计算结果与Excel匹配
#
# 行号：262
# ------------------------------
# 第7列 (CO2-3) 的值：14.721822738647461
# 第16列 (CO2-4) 的值：1.685370922088623
# 最后一列 (CO2 capacity) 的值：0.8855188686884391
#
# 计算结果：0.885519
# ✓ 计算结果与Excel匹配
#
# 行号：263
# ------------------------------
# 第7列 (CO2-3) 的值：14.721822738647461
# 第16列 (CO2-4) 的值：1.5885899066925049
# 最后一列 (CO2 capacity) 的值：0.8920928518910796
#
# 计算结果：0.892093
# ✓ 计算结果与Excel匹配
#
# 行号：264
# ------------------------------
# 第7列 (CO2-3) 的值：14.721822738647461
# 第16列 (CO2-4) 的值：1.730540156364441
# 最后一列 (CO2 capacity) 的值：0.8824506865021912
#
# 计算结果：0.882451
# ✓ 计算结果与Excel匹配
#
# 行号：265
# ------------------------------
# 第7列 (CO2-3) 的值：15.55744743347168
# 第16列 (CO2-4) 的值：1.7829376459121704
# 最后一列 (CO2 capacity) 的值：0.8853965180639981
#
# 计算结果：0.885397
# ✓ 计算结果与Excel匹配
#
# 行号：266
# ------------------------------
# 第7列 (CO2-3) 的值：15.442867279052734
# 第16列 (CO2-4) 的值：1.7536988258361816
# 最后一列 (CO2 capacity) 的值：0.886439558525834
#
# 计算结果：0.886440
# ✓ 计算结果与Excel匹配
#
# 行号：267
# ------------------------------
# 第7列 (CO2-3) 的值：15.015375137329102
# 第16列 (CO2-4) 的值：1.7961949110031128
# 最后一列 (CO2 capacity) 的值：0.8803762879997805
#
# 计算结果：0.880376
# ✓ 计算结果与Excel匹配
#
# 行号：268
# ------------------------------
# 第7列 (CO2-3) 的值：15.239169120788574
# 第16列 (CO2-4) 的值：1.7376842498779297
# 最后一列 (CO2 capacity) 的值：0.8859725070241881
#
# 计算结果：0.885973
# ✓ 计算结果与Excel匹配
#
# 行号：269
# ------------------------------
# 第7列 (CO2-3) 的值：15.50183391571045
# 第16列 (CO2-4) 的值：1.7990190982818604
# ...
# 第16列 (CO2-4) 的值：1.920781135559082
# 最后一列 (CO2 capacity) 的值：0.8746146930187985
#
# 计算结果：0.874615
# ✓ 计算结果与Excel匹配
#
# 行号：547
# ------------------------------
# 第7列 (CO2-3) 的值：15.233200073242188
# 第16列 (CO2-4) 的值：1.9394575357437134
# 最后一列 (CO2 capacity) 的值：0.8726821989851982
#
# 计算结果：0.872682
# ✓ 计算结果与Excel匹配
#
# 行号：548
# ------------------------------
# 第7列 (CO2-3) 的值：15.123858451843262
# 第16列 (CO2-4) 的值：1.9233760833740234
# 最后一列 (CO2 capacity) 的值：0.8728250406800384
#
# 计算结果：0.872825
# ✓ 计算结果与Excel匹配
#
# 行号：549
# ------------------------------
# 第7列 (CO2-3) 的值：15.325393676757812
# 第16列 (CO2-4) 的值：1.950467824935913
# 最后一列 (CO2 capacity) 的值：0.8727296755910451
#
# 计算结果：0.872730
# ✓ 计算结果与Excel匹配
#
# 行号：550
# ------------------------------
# 第7列 (CO2-3) 的值：15.31908893585205
# 第16列 (CO2-4) 的值：1.9533460140228271
# 最后一列 (CO2 capacity) 的值：0.872489413554398
#
# 计算结果：0.872489
# ✓ 计算结果与Excel匹配
#
# 行号：551
# ------------------------------
# 第7列 (CO2-3) 的值：15.267312049865723
# 第16列 (CO2-4) 的值：1.9474070072174072
# 最后一列 (CO2 capacity) 的值：0.8724459812665888
#
# 计算结果：0.872446
# ✓ 计算结果与Excel匹配
#
# 行号：552
# ------------------------------
# 第7列 (CO2-3) 的值：15.379212379455566
# 第16列 (CO2-4) 的值：1.9872723817825317
# 最后一列 (CO2 capacity) 的值：0.8707819143952232
#
# 计算结果：0.870782
# ✓ 计算结果与Excel匹配
#
# 行号：553
# ------------------------------
# 第7列 (CO2-3) 的值：15.264571189880371
# 第16列 (CO2-4) 的值：1.9879759550094604
# 最后一列 (CO2 capacity) 的值：0.8697653586019248
#
# 计算结果：0.869765
# ✓ 计算结果与Excel匹配
#
# 行号：554
# ------------------------------
# 第7列 (CO2-3) 的值：15.373303413391113
# 第16列 (CO2-4) 的值：1.9750012159347534
# 最后一列 (CO2 capacity) 的值：0.8715304601212512
#
# 计算结果：0.871530
# ✓ 计算结果与Excel匹配
#
# 行号：555
# ------------------------------
# 第7列 (CO2-3) 的值：15.402938842773438
# 第16列 (CO2-4) 的值：2.0127925872802734
# 最后一列 (CO2 capacity) 的值：0.869324120038001
#
# 计算结果：0.869324
# ✓ 计算结果与Excel匹配
#
# 行号：556
# ------------------------------
# 第7列 (CO2-3) 的值：15.324267387390137
# 第16列 (CO2-4) 的值：2.012920618057251
# 最后一列 (CO2 capacity) 的值：0.8686449037222086
#
# 计算结果：0.868645
# ✓ 计算结果与Excel匹配
#
# 行号：557
# ------------------------------
# 第7列 (CO2-3) 的值：15.476249694824219
# 第16列 (CO2-4) 的值：1.9891637563705444
# 最后一列 (CO2 capacity) 的值：0.8714699106311403
#
# 计算结果：0.871470
# ✓ 计算结果与Excel匹配
#
# 行号：558
# ------------------------------
# 第7列 (CO2-3) 的值：15.354328155517578
# 第16列 (CO2-4) 的值：1.990050196647644
# 最后一列 (CO2 capacity) 的值：0.8703915810258022
#
# 计算结果：0.870392
# ✓ 计算结果与Excel匹配
#
# 行号：559
# ------------------------------
# 第7列 (CO2-3) 的值：15.418989181518555
# 第16列 (CO2-4) 的值：2.0027782917022705
# 最后一列 (CO2 capacity) 的值：0.8701096246890923
#
# 计算结果：0.870110
# ✓ 计算结果与Excel匹配
#
# 行号：560
# ------------------------------
# 第7列 (CO2-3) 的值：15.214349746704102
# 第16列 (CO2-4) 的值：2.0151844024658203
# 最后一列 (CO2 capacity) 的值：0.8675471225510396
#
# 计算结果：0.867547
# ✓ 计算结果与Excel匹配
#
# 行号：561
# ------------------------------
# 第7列 (CO2-3) 的值：15.173199653625488
# 第16列 (CO2-4) 的值：1.9978623390197754
# 最后一列 (CO2 capacity) 的值：0.8683295293921474
#
# 计算结果：0.868330
# ✓ 计算结果与Excel匹配
#
# 行号：562
# ------------------------------
# 第7列 (CO2-3) 的值：15.369953155517578
# 第16列 (CO2-4) 的值：1.9877018928527832
# 最后一列 (CO2 capacity) 的值：0.8706761255066526
#
# 计算结果：0.870676
# ✓ 计算结果与Excel匹配
#
# 行号：563
# ------------------------------
# 第7列 (CO2-3) 的值：15.235697746276855
# 第16列 (CO2-4) 的值：2.0075843334198
# 最后一列 (CO2 capacity) 的值：0.8682315462768752
#
# 计算结果：0.868232
# ✓ 计算结果与Excel匹配
#
# 行号：564
# ------------------------------
# 第7列 (CO2-3) 的值：15.558026313781738
# 第16列 (CO2-4) 的值：2.0119245052337646
# 最后一列 (CO2 capacity) 的值：0.870682536161316
#
# 计算结果：0.870683
# ✓ 计算结果与Excel匹配
#
# 行号：565
# ------------------------------
# 第7列 (CO2-3) 的值：15.36629867553711
# 第16列 (CO2-4) 的值：2.033022165298462
# 最后一列 (CO2 capacity) 的值：0.8676960400011619
#
# 计算结果：0.867696
# ✓ 计算结果与Excel匹配
#
# 行号：566
# ------------------------------
# 第7列 (CO2-3) 的值：15.33523178100586
# 第16列 (CO2-4) 的值：2.077721357345581
# 最后一列 (CO2 capacity) 的值：0.8645132080808171
#
# 计算结果：0.864513
# ✓ 计算结果与Excel匹配
#
# 行号：567
# ------------------------------
# 第7列 (CO2-3) 的值：15.292987823486328
# 第16列 (CO2-4) 的值：2.0657424926757812
# 最后一列 (CO2 capacity) 的值：0.864922243022825
#
# 计算结果：0.864922
# ✓ 计算结果与Excel匹配
#
# 行号：568
# ------------------------------
# 第7列 (CO2-3) 的值：15.294114112854004
# 第16列 (CO2-4) 的值：2.071032762527466
# 最后一列 (CO2 capacity) 的值：0.8645862880814484
#
# 计算结果：0.864586
# ✓ 计算结果与Excel匹配
#
# 行号：569
# ------------------------------
# 第7列 (CO2-3) 的值：15.214864730834961
# 第16列 (CO2-4) 的值：2.0534164905548096
# 最后一列 (CO2 capacity) 的值：0.8650387941738787
#
# 计算结果：0.865039
# ✓ 计算结果与Excel匹配
#
# 行号：570
# ------------------------------
# 第7列 (CO2-3) 的值：15.295881271362305
# 第16列 (CO2-4) 的值：2.0398752689361572
# 最后一列 (CO2 capacity) 的值：0.8666389184940059
#
# 计算结果：0.866639
# ✓ 计算结果与Excel匹配
#
# 行号：571
# ------------------------------
# 第7列 (CO2-3) 的值：15.22528076171875
# 第16列 (CO2-4) 的值：2.065916061401367
# 最后一列 (CO2 capacity) 的值：0.8643101500895968
#
# 计算结果：0.864310
# ✓ 计算结果与Excel匹配
#
# 行号：572
# ------------------------------
# 第7列 (CO2-3) 的值：15.265789031982422
# 第16列 (CO2-4) 的值：2.0468194484710693
# 最后一列 (CO2 capacity) 的值：0.8659211492977597
#
# 计算结果：0.865921
# ✓ 计算结果与Excel匹配
#
# 行号：573
# ------------------------------
# 第7列 (CO2-3) 的值：15.307455062866211
# 第16列 (CO2-4) 的值：2.0468194484710693
# 最后一列 (CO2 capacity) 的值：0.8662861043808403
#
# 计算结果：0.866286
# ✓ 计算结果与Excel匹配
#
# 行号：574
# ------------------------------
# 第7列 (CO2-3) 的值：15.326398849487305
# 第16列 (CO2-4) 的值：2.0619871616363525
# 最后一列 (CO2 capacity) 的值：0.8654617316248866
#
# 计算结果：0.865462
# ✓ 计算结果与Excel匹配
#
# 行号：575
# ------------------------------
# 第7列 (CO2-3) 的值：15.33523178100586
# 第16列 (CO2-4) 的值：2.0950818061828613
# 最后一列 (CO2 capacity) 的值：0.8633811450585429
#
# 计算结果：0.863381
# ✓ 计算结果与Excel匹配
#
# 行号：576
# ------------------------------
# 第7列 (CO2-3) 的值：15.484533309936523
# 第16列 (CO2-4) 的值：2.1107065677642822
# 最后一列 (CO2 capacity) 的值：0.8636893650253038
#
# 计算结果：0.863689
# ✓ 计算结果与Excel匹配
#
# 行号：577
# ------------------------------
# 第7列 (CO2-3) 的值：15.426908493041992
# 第16列 (CO2-4) 的值：2.1071248054504395
# 最后一列 (CO2 capacity) 的值：0.8634123741382911
#
# 计算结果：0.863412
# ✓ 计算结果与Excel匹配
#
# 行号：578
# ------------------------------
# 第7列 (CO2-3) 的值：15.351434707641602
# 第16列 (CO2-4) 的值：2.1245951652526855
# 最后一列 (CO2 capacity) 的值：0.8616028269856035
#
# 计算结果：0.861603
# ✓ 计算结果与Excel匹配
#
# 行号：579
# ------------------------------
# 第7列 (CO2-3) 的值：15.286622047424316
# 第16列 (CO2-4) 的值：2.111748218536377
# 最后一列 (CO2 capacity) 的值：0.8618564512169521
#
# 计算结果：0.861856
# ✓ 计算结果与Excel匹配
#
# 行号：580
# ------------------------------
# 第7列 (CO2-3) 的值：15.377872467041016
# 第16列 (CO2-4) 的值：2.109043598175049
# 最后一列 (CO2 capacity) 的值：0.8628520555951218
#
# 计算结果：0.862852
# ✓ 计算结果与Excel匹配
#
# 行号：581
# ------------------------------
# 第7列 (CO2-3) 的值：15.52041244506836
# 第16列 (CO2-4) 的值：2.077721357345581
# 最后一列 (CO2 capacity) 的值：0.8661297588128348
#
# 计算结果：0.866130
# ✓ 计算结果与Excel匹配
#
# 行号：582
# ------------------------------
# 第7列 (CO2-3) 的值：15.479325294494629
# 第16列 (CO2-4) 的值：2.088658571243286
# 最后一列 (CO2 capacity) 的值：0.8650678546056437
#
# 计算结果：0.865068
# ✓ 计算结果与Excel匹配
#
# 行号：583
# ------------------------------
# 第7列 (CO2-3) 的值：15.353201866149902
# 第16列 (CO2-4) 的值：2.1119675636291504
# 最后一列 (CO2 capacity) 的值：0.8624412300416939
#
# 计算结果：0.862441
# ✓ 计算结果与Excel匹配
#
# 行号：584
# ------------------------------
# 第7列 (CO2-3) 的值：15.301668167114258
# 第16列 (CO2-4) 的值：2.111053705215454
# 最后一列 (CO2 capacity) 的值：0.862037675751429
#
# 计算结果：0.862038
# ✓ 计算结果与Excel匹配
#
# 行号：585
# ------------------------------
# 第7列 (CO2-3) 的值：15.227595329284668
# 第16列 (CO2-4) 的值：2.0718185901641846
# 最后一列 (CO2 capacity) 的值：0.8639431541643476
#
# 计算结果：0.863943
# ✓ 计算结果与Excel匹配
#
# 行号：586
# ------------------------------
# 第7列 (CO2-3) 的值：15.39127254486084
# 第16列 (CO2-4) 的值：2.0677435398101807
# 最后一列 (CO2 capacity) 的值：0.8656548031500747
#
# 计算结果：0.865655
# ✓ 计算结果与Excel匹配
#
# 行号：587
# ------------------------------
# 第7列 (CO2-3) 的值：15.358379364013672
# 第16列 (CO2-4) 的值：2.0120980739593506
# 最后一列 (CO2 capacity) 的值：0.8689902087798461
#
# 计算结果：0.868990
# ✓ 计算结果与Excel匹配
#
# 行号：588
# ------------------------------
# 第7列 (CO2-3) 的值：15.339860916137695
# 第16列 (CO2-4) 的值：2.029285192489624
# 最后一列 (CO2 capacity) 的值：0.8677116302694248
#
# 计算结果：0.867712
# ✓ 计算结果与Excel匹配
#
# 行号：589
# ------------------------------
# 第7列 (CO2-3) 的值：15.390664100646973
# 第16列 (CO2-4) 的值：2.029184579849243
# 最后一列 (CO2 capacity) 的值：0.8681548394156726
#
# 计算结果：0.868155
# ✓ 计算结果与Excel匹配
#
# 行号：590
# ------------------------------
# 第7列 (CO2-3) 的值：15.323657989501953
# 第16列 (CO2-4) 的值：2.0864017009735107
# 最后一列 (CO2 capacity) 的值：0.8638444095787782
#
# 计算结果：0.863844
# ✓ 计算结果与Excel匹配
#
# 行号：591
# ------------------------------
# 第7列 (CO2-3) 的值：15.41046142578125
# 第16列 (CO2-4) 的值：2.0914361476898193
# 最后一列 (CO2 capacity) 的值：0.86428465119215
#
# 计算结果：0.864285
# ✓ 计算结果与Excel匹配
#
# 行号：592
# ------------------------------
# 第7列 (CO2-3) 的值：15.553305625915527
# 第16列 (CO2-4) 的值：2.0713984966278076
# 最后一列 (CO2 capacity) 的值：0.8668194050545523
#
# 计算结果：0.866819
# ✓ 计算结果与Excel匹配
#
# 行号：593
# ------------------------------
# 第7列 (CO2-3) 的值：15.438238143920898
# 第16列 (CO2-4) 的值：2.145775079727173
# 最后一列 (CO2 capacity) 的值：0.8610090698353353
#
# 计算结果：0.861009
# ✓ 计算结果与Excel匹配
#
# 行号：594
# ------------------------------
# 第7列 (CO2-3) 的值：15.450969696044922
# 第16列 (CO2-4) 的值：2.1360530853271484
# 最后一列 (CO2 capacity) 的值：0.8617528137490343
#
# 计算结果：0.861753
# ✓ 计算结果与Excel匹配
#
# 行号：595
# ------------------------------
# 第7列 (CO2-3) 的值：15.452796936035156
# 第16列 (CO2-4) 的值：2.1234803199768066
# 最后一列 (CO2 capacity) 的值：0.8625827849309948
#
# 计算结果：0.862583
# ✓ 计算结果与Excel匹配
#
# 行号：596
# ------------------------------
# 第7列 (CO2-3) 的值：15.5042085647583
# 第16列 (CO2-4) 的值：2.1329283714294434
# 最后一列 (CO2 capacity) 的值：0.8624290712730944
#
# 计算结果：0.862429
# ✓ 计算结果与Excel匹配
#
# 行号：597
# ------------------------------
# 第7列 (CO2-3) 的值：15.520411491394043
# 第16列 (CO2-4) 的值：2.167649507522583
# 最后一列 (CO2 capacity) 的值：0.860335564638571
#
# 计算结果：0.860336
# ✓ 计算结果与Excel匹配
#
# 行号：598
# ------------------------------
# 第7列 (CO2-3) 的值：15.529167175292969
# 第16列 (CO2-4) 的值：2.148267984390259
# 最后一列 (CO2 capacity) 的值：0.8616623827832718
#
# 计算结果：0.861662
# ✓ 计算结果与Excel匹配
#
# 行号：599
# ------------------------------
# 第7列 (CO2-3) 的值：15.255373001098633
# 第16列 (CO2-4) 的值：2.2186896800994873
# 最后一列 (CO2 capacity) 的值：0.8545633935047209
#
# 计算结果：0.854563
# ✓ 计算结果与Excel匹配
#
# 行号：600
# ------------------------------
# 第7列 (CO2-3) 的值：15.569600105285645
# 第16列 (CO2-4) 的值：2.160184383392334
# 最后一列 (CO2 capacity) 的值：0.8612562706309339
#
# 计算结果：0.861256
# ✓ 计算结果与Excel匹配
#
# 行号：601
# ------------------------------
# 第7列 (CO2-3) 的值：15.534615516662598
# 第16列 (CO2-4) 的值：2.177971124649048
# 最后一列 (CO2 capacity) 的值：0.8597988394168538
#
# 计算结果：0.859799
# ✓ 计算结果与Excel匹配
#
# 行号：602
# ------------------------------
# 第7列 (CO2-3) 的值：15.320185661315918
# 第16列 (CO2-4) 的值：2.1732048988342285
# 最后一列 (CO2 capacity) 的值：0.8581476134247081
#
# 计算结果：0.858148
# ✓ 计算结果与Excel匹配
#
# 行号：603
# ------------------------------
# 第7列 (CO2-3) 的值：15.441710472106934
# 第16列 (CO2-4) 的值：2.1200814247131348
# 最后一列 (CO2 capacity) 的值：0.8627042367785139
#
# 计算结果：0.862704
# ✓ 计算结果与Excel匹配
#
# 行号：604
# ------------------------------
# 第7列 (CO2-3) 的值：15.387839317321777
# 第16列 (CO2-4) 的值：2.0996904373168945
# 最后一列 (CO2 capacity) 的值：0.8635487157086885
#
# 计算结果：0.863549
# ✓ 计算结果与Excel匹配
#
# 行号：605
# ------------------------------
# 第7列 (CO2-3) 的值：15.507680892944336
# 第16列 (CO2-4) 的值：2.085360050201416
# 最后一列 (CO2 capacity) 的值：0.8655272787338427
#
# 计算结果：0.865527
# ✓ 计算结果与Excel匹配
#
# 行号：606
# ------------------------------
# 第7列 (CO2-3) 的值：15.248428344726562
# 第16列 (CO2-4) 的值：2.1061928272247314
# 最后一列 (CO2 capacity) 的值：0.8618747598369293
#
# 计算结果：0.861875
# ✓ 计算结果与Excel匹配
#
# 行号：607
# ------------------------------
# 第7列 (CO2-3) 的值：15.36048412322998
# 第16列 (CO2-4) 的值：2.0873801708221436
# 最后一列 (CO2 capacity) 的值：0.8641071365930872
#
# 计算结果：0.864107
# ✓ 计算结果与Excel匹配
#
# 行号：608
# ------------------------------
# 第7列 (CO2-3) 的值：15.234539985656738
# 第16列 (CO2-4) 的值：2.088832139968872
# 最后一列 (CO2 capacity) 的值：0.8628884008355028
#
# 计算结果：0.862888
# ✓ 计算结果与Excel匹配
#
# 行号：609
# ------------------------------
# 第7列 (CO2-3) 的值：15.331759452819824
# 第16列 (CO2-4) 的值：2.059666395187378
# 最后一列 (CO2 capacity) 的值：0.8656601415169892
#
# 计算结果：0.865660
# ✓ 计算结果与Excel匹配
#
# 行号：610
# ------------------------------
# 第7列 (CO2-3) 的值：15.384157180786133
# 第16列 (CO2-4) 的值：2.0611815452575684
# 最后一列 (CO2 capacity) 的值：0.866019209175017
#
# 计算结果：0.866019
# ✓ 计算结果与Excel匹配
#
# 行号：611
# ------------------------------
# 第7列 (CO2-3) 的值：15.331759452819824
# 第16列 (CO2-4) 的值：2.081193447113037
# 最后一列 (CO2 capacity) 的值：0.8642560592267665
#
# 计算结果：0.864256
# ✓ 计算结果与Excel匹配
#
# 行号：612
# ------------------------------
# 第7列 (CO2-3) 的值：15.416248321533203
# 第16列 (CO2-4) 的值：2.078068494796753
# 最后一列 (CO2 capacity) 的值：0.8652027100592213
#
# 计算结果：0.865203
# ✓ 计算结果与Excel匹配
#
# 行号：613
# ------------------------------
# 第7列 (CO2-3) 的值：15.263158798217773
# 第16列 (CO2-4) 的值：2.071124315261841
# 最后一列 (CO2 capacity) 的值：0.8643056563426649
#
# 计算结果：0.864306
# ✓ 计算结果与Excel匹配
#
# 行号：614
# ------------------------------
# 第7列 (CO2-3) 的值：15.298195838928223
# 第16列 (CO2-4) 的值：2.0419585704803467
# 最后一列 (CO2 capacity) 的值：0.8665229160366531
#
# 计算结果：0.866523
# ✓ 计算结果与Excel匹配
#
# 行号：615
# ------------------------------
# 第7列 (CO2-3) 的值：15.384420394897461
# 第16列 (CO2-4) 的值：2.0265073776245117
# 最后一列 (CO2 capacity) 的值：0.868275350932516
#
# 计算结果：0.868275
# ✓ 计算结果与Excel匹配
#
# 行号：616
# ------------------------------
# 第7列 (CO2-3) 的值：15.22528076171875
# 第16列 (CO2-4) 的值：2.0463459491729736
# 最后一列 (CO2 capacity) 的值：0.8655955196361209
#
# 计算结果：0.865596
# ✓ 计算结果与Excel匹配
#
# 行号：617
# ------------------------------
# 第7列 (CO2-3) 的值：15.316713333129883
# 第16列 (CO2-4) 的值：2.019042491912842
# 最后一列 (CO2 capacity) 的值：0.8681804347969564
#
# 计算结果：0.868180
# ✓ 计算结果与Excel匹配
#
# 行号：618
# ------------------------------
# 第7列 (CO2-3) 的值：15.309769630432129
# 第16列 (CO2-4) 的值：2.013834238052368
# 最后一列 (CO2 capacity) 的值：0.8684608399299915
#
# 计算结果：0.868461
# ✓ 计算结果与Excel匹配
#
# 行号：619
# ------------------------------
# 第7列 (CO2-3) 的值：15.321027755737305
# 第16列 (CO2-4) 的值：2.0256710052490234
# 最后一列 (CO2 capacity) 的值：0.8677849138096845
#
# 计算结果：0.867785
# ✓ 计算结果与Excel匹配
#
# 行号：620
# ------------------------------
# 第7列 (CO2-3) 的值：15.439395904541016
# 第16列 (CO2-4) 的值：2.029111623764038
# 最后一列 (CO2 capacity) 的值：0.8685757113613987
#
# 计算结果：0.868576
# ✓ 计算结果与Excel匹配
#
# 行号：621
# ------------------------------
# 第7列 (CO2-3) 的值：15.24958610534668
# 第16列 (CO2-4) 的值：2.047166585922241
# 最后一列 (CO2 capacity) 的值：0.8657559246670649
#
# 计算结果：0.865756
# ✓ 计算结果与Excel匹配
#
# 行号：622
# ------------------------------
# 第7列 (CO2-3) 的值：15.19687271118164
# 第16列 (CO2-4) 的值：2.013045072555542
# 最后一列 (CO2 capacity) 的值：0.8675355705865475
#
# 计算结果：0.867536
# ✓ 计算结果与Excel匹配
#
# 行号：623
# ------------------------------
# 第7列 (CO2-3) 的值：15.481060981750488
# 第16列 (CO2-4) 的值：1.9725159406661987
# 最后一列 (CO2 capacity) 的值：0.8725852224862717
#
# 计算结果：0.872585
# ✓ 计算结果与Excel匹配
#
# 行号：624
# ------------------------------
# 第7列 (CO2-3) 的值：15.419720649719238
# 第16列 (CO2-4) 的值：2.0178403854370117
# 最后一列 (CO2 capacity) 的值：0.8691389791504587
#
# 计算结果：0.869139
# ✓ 计算结果与Excel匹配
#
# 行号：625
# ------------------------------
# 第7列 (CO2-3) 的值：15.281044960021973
# 第16列 (CO2-4) 的值：2.0570778846740723
# 最后一列 (CO2 capacity) 的值：0.8653836900515791
#
# 计算结果：0.865384
# ✓ 计算结果与Excel匹配
#
# 行号：626
# ------------------------------
# 第7列 (CO2-3) 的值：15.288936614990234
# 第16列 (CO2-4) 的值：2.052027702331543
# 最后一列 (CO2 capacity) 的值：0.8657834907681149
#
# 计算结果：0.865783
# ✓ 计算结果与Excel匹配
#
# 行号：627
# ------------------------------
# 第7列 (CO2-3) 的值：15.20792007446289
# 第16列 (CO2-4) 的值：2.032017230987549
# 最后一列 (CO2 capacity) 的值：0.8663842773345641
#
# 计算结果：0.866384
# ✓ 计算结果与Excel匹配
#
# 行号：628
# ------------------------------
# 第7列 (CO2-3) 的值：15.227385520935059
# 第16列 (CO2-4) 的值：2.0332465171813965
# 最后一列 (CO2 capacity) 的值：0.8664743521213126
#
# 计算结果：0.866474
# ✓ 计算结果与Excel匹配
#
# 行号：629
# ------------------------------
# 第7列 (CO2-3) 的值：15.382684707641602
# 第16列 (CO2-4) 的值：2.025986671447754
# 最后一列 (CO2 capacity) 的值：0.8682943380851256
#
# 计算结果：0.868294
# ✓ 计算结果与Excel匹配
#
# 行号：630
# ------------------------------
# 第7列 (CO2-3) 的值：15.19604206085205
# 第16列 (CO2-4) 的值：2.0501089096069336
# 最后一列 (CO2 capacity) 的值：0.8650892843414528
#
# 计算结果：0.865089
# ✓ 计算结果与Excel匹配
#
# 行号：631
# ------------------------------
# 第7列 (CO2-3) 的值：15.433609008789062
# 第16列 (CO2-4) 的值：2.081382989883423
# 最后一列 (CO2 capacity) 的值：0.8651395802045959
#
# 计算结果：0.865140
# ✓ 计算结果与Excel匹配
#
# 行号：632
# ------------------------------
# 第7列 (CO2-3) 的值：15.375740051269531
# 第16列 (CO2-4) 的值：2.1023733615875244
# 最后一列 (CO2 capacity) 的值：0.8632668505985871
#
# 计算结果：0.863267
# ✓ 计算结果与Excel匹配
#
# 行号：633
# ------------------------------
# 第7列 (CO2-3) 的值：15.465893745422363
# 第16列 (CO2-4) 的值：2.057966709136963
# 最后一列 (CO2 capacity) 的值：0.8669351579021364
#
# 计算结果：0.866935
# ✓ 计算结果与Excel匹配
#
# 行号：634
# ------------------------------
# 第7列 (CO2-3) 的值：15.49726390838623
# 第16列 (CO2-4) 的值：2.055341958999634
# 最后一列 (CO2 capacity) 的值：0.8673738815348301
#
# 计算结果：0.867374
# ✓ 计算结果与Excel匹配
#
# ==================================================
# 计算总结：
# 总计算行数：633
# 匹配成功行数：633
# 成功率：100.00%
